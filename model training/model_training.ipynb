# %% [markdown]
# # Voice Fingerprint model training using GMM Models

# %%
import os
import time
import pickle
import numpy as np
from sklearn import preprocessing
from scipy.io.wavfile import read
import python_speech_features as mfcc
from sklearn.mixture import GaussianMixture

# %% [markdown]
# ## Functions

# %%
# function to calculate and returns the delta of given feature vector matrix
def calculate_delta(array):
    rows,cols = array.shape
    # print(rows)
    # print(cols)
    deltas = np.zeros((rows,20))
    N = 2
    for i in range(rows):
        index = []
        j = 1
        while j <= N:
            if i-j < 0:
                first =0
            else:
                first = i-j
            if i+j > rows-1:
                second = rows-1
            else:
                second = i+j 
            index.append((second,first))
            j+=1
        deltas[i] = ( array[index[0][0]]-array[index[0][1]] + (2 * (array[index[1][0]]-array[index[1][1]])) ) / 10
    return deltas

# %%
# function to extract mfcc and delta features from audio and return them in a combined matrix
def extract_features(audio,rate):
    mfcc_feature = mfcc.mfcc(audio,rate, 0.025, 0.01,20,nfft = 1200, appendEnergy = True)    
    mfcc_feature = preprocessing.scale(mfcc_feature)
    # print(mfcc_feature)
    delta = calculate_delta(mfcc_feature)
    combined = np.hstack((mfcc_feature,delta)) 
    return combined

# %%
# function to train the models
def train_model(data_set_name , model_name):
	SAMPLES_NUMBER = 5
	source = f"data_set\\{data_set_name}\\"   					 #trained set path
	dest  =  f"trained_models\\{model_name}\\"     				 #destination path to store trained models
	train_file = f"data_set\\{data_set_name}_addition.txt"     #training file with sample names   
	file_paths = open(train_file,'r')
	count = 1
	features = np.asarray(())
	for path in file_paths:    
		path = path.strip()   
		print(path)
		sr,audio = read(source + path)
		print(sr)
		vector   = extract_features(audio,sr)
		if features.size == 0:
			features = vector
		else:
			features = np.vstack((features, vector))
		
		if count == SAMPLES_NUMBER:    
			gmm = GaussianMixture(n_components = 10, max_iter = 300, covariance_type='diag',n_init = 1)
			gmm.fit(features) 
			
			# dumping the trained gaussian model
			print(path)
			picklefile = path.split("\\")[0]+".gmm"
			print(picklefile)

			pickle.dump(gmm,open(dest + picklefile,'wb'))
			print('+ modeling completed for speaker:',picklefile," with data point = ",features.shape)   
			features = np.asarray(())
			count = 0
		count = count + 1

# %%
# function to test models and predict the speaker or sentence
def test_model(model_name):
	source   = "data_set\\testing_set\\"  #path of test samples
	modelpath = f"trained_models\\{model_name}\\" #path of trained models
	test_file = "data_set\\testing_set_addition.txt"       #test samples names
	file_paths = open(test_file,'r')

	gmm_files = [os.path.join(modelpath,fname) for fname in
				os.listdir(modelpath) if fname.endswith('.gmm')]
	
	#Load the Gaussian gender Models
	models    = [pickle.load(open(fname,'rb')) for fname in gmm_files]
	speakers   = [fname.split("\\")[-1].split(".gmm")[0] for fname in gmm_files]

	# Read the test directory and get the list of test audio files 
	for path in file_paths:   
		path = path.strip()   
		print(f"Test File : {path}\n")
		sr,audio = read(source + path)
		vector   = extract_features(audio,sr)
		log_likelihood = np.zeros(len(models)); 
		max_score=-100
		for i in range(len(models)):
			gmm    = models[i]  #checking with each model one by one
			scores = np.array(gmm.score(vector))
			if scores > max_score:
				max_score = scores
			print(gmm_files[i].split("\\")[-1])
			print(scores)
			log_likelihood[i] = scores.sum()
		winner = np.argmax(log_likelihood)
		print("\tdetected as - ", speakers[winner])
		print(f"MaxScore = {max_score}")
		print("-"*50)
		# detecting by threshold score
		if max_score > -24:
			print("Accepted")
		else :
			print("Other")
		print("#"*50)
		time.sleep(1.0)

# %% [markdown]
# ## Models Training

# %%
# train teams models
train_model("teams_training_set" , "Team_Verification")
# Out:
# Neveen\open_door_neveen-sample1.wav
# 44100
# Neveen\open_door_neveen-sample2.wav
# 44100
# Neveen\open_door_neveen-sample3.wav
# 44100
# Neveen\open_door_neveen-sample4.wav
# 44100
# Neveen\open_door_neveen-sample5.wav
# 44100
# Neveen\open_door_neveen-sample5.wav
# Neveen.gmm
# + modeling completed for speaker: Neveen.gmm  with data point =  (995, 40)
# Nurhan\open_the_door_nourhan-sample1.wav
# 44100
# Nurhan\open_the_door_nourhan-sample2.wav
# 44100
# Nurhan\open_the_door_nourhan-sample3.wav
# 44100
# Nurhan\open_the_door_nourhan-sample4.wav
# 44100
# Nurhan\open_the_door_nourhan-sample5.wav
# 44100
# Nurhan\open_the_door_nourhan-sample5.wav
# Nurhan.gmm
# + modeling completed for speaker: Nurhan.gmm  with data point =  (995, 40)
# Omar\omar_open_door-sample0.wav
# 44100
# Omar\omar_open_door-sample1.wav
# 44100
# Omar\omar_open_door-sample2.wav
# 44100
# Omar\omar_open_door-sample3.wav
# 44100
# Omar\Open_The_Door_Omar-sample7.wav
# 44100
# Omar\Open_The_Door_Omar-sample7.wav
# Omar.gmm
# + modeling completed for speaker: Omar.gmm  with data point =  (995, 40)
# Others_1\Ahmed Emad (6).wav
# 44100
# Others_1\Ahmed Emad (7).wav
# 44100
# Others_1\Mariam Ezzat (7).wav
# 44100
# Others_1\Mariam Ezzat (8).wav
# 44100
# Others_1\Mayar Fayez (8).wav
# 44100
# Others_1\Mayar Fayez (8).wav
# Others_1.gmm
# + modeling completed for speaker: Others_1.gmm  with data point =  (807, 40)
# Other_2\Mahmoud-sample3.wav
# 44100
# Other_2\Moamen_Open-sample11.wav
# 44100
# Other_2\Moamen_Open-sample5.wav
# 44100
# Other_2\Zeyad_Open-sample5.wav
# 44100
# Other_2\Zeyad_Open-sample9.wav
# 44100
# Other_2\Zeyad_Open-sample9.wav
# Other_2.gmm
# + modeling completed for speaker: Other_2.gmm  with data point =  (995, 40)
# Other_3\Sara Amgad (3).wav
# 44100
# Other_3\Sara Amgad (4).wav
# 44100
# Other_3\Youssif Essam (2).wav
# 44100
# Other_3\Youssif Essam (3).wav
# 44100
# Other_3\zeyad12.wav
# 44100
# Other_3\zeyad12.wav
# Other_3.gmm
# + modeling completed for speaker: Other_3.gmm  with data point =  (726, 40)
# Salman\open_the_door_salman-sample1.wav
# 44100
# Salman\open_the_door_salman-sample2.wav
# 44100
# Salman\open_the_door_salman-sample3.wav
# 44100
# Salman\open_the_door_salman-sample5.wav
# 44100
# Salman\salman.wav
# 44100
# Salman\salman.wav
# Salman.gmm
# + modeling completed for speaker: Salman.gmm  with data point =  (995, 40)

# %%
#train sentence models
train_model("sentence_training_set" , "Sentence_Verification")
# Out:
# Neveen_Close_The_Door\close_door_neveen-sample0.wav
# 44100
# Neveen_Close_The_Door\close_door_neveen-sample1.wav
# 44100
# Neveen_Close_The_Door\close_door_neveen-sample2.wav
# 44100
# Neveen_Close_The_Door\close_door_neveen-sample3.wav
# 44100
# Neveen_Close_The_Door\close_door_neveen-sample4.wav
# 44100
# Neveen_Close_The_Door\close_door_neveen-sample4.wav
# Neveen_Close_The_Door.gmm
# + modeling completed for speaker: Neveen_Close_The_Door.gmm  with data point =  (995, 40)
# Neveen_Close_The_Window\close_window_neveen-sample0.wav
# 44100
# Neveen_Close_The_Window\close_window_neveen-sample1.wav
# 44100
# Neveen_Close_The_Window\close_window_neveen-sample2.wav
# 44100
# Neveen_Close_The_Window\close_window_neveen-sample3.wav
# 44100
# Neveen_Close_The_Window\close_window_neveen-sample4.wav
# 44100
# Neveen_Close_The_Window\close_window_neveen-sample4.wav
# Neveen_Close_The_Window.gmm
# + modeling completed for speaker: Neveen_Close_The_Window.gmm  with data point =  (995, 40)
# Neveen_Open_The_Door\open_door_neveen-sample0.wav
# 44100
# Neveen_Open_The_Door\open_door_neveen-sample1.wav
# 44100
# Neveen_Open_The_Door\open_door_neveen-sample2.wav
# 44100
# Neveen_Open_The_Door\open_door_neveen-sample3.wav
# 44100
# Neveen_Open_The_Door\open_door_neveen-sample4.wav
# 44100
# Neveen_Open_The_Door\open_door_neveen-sample4.wav
# Neveen_Open_The_Door.gmm
# + modeling completed for speaker: Neveen_Open_The_Door.gmm  with data point =  (995, 40)
# Neveen_Open_The_Window\open_window_neveen-sample0.wav
# 44100
# Neveen_Open_The_Window\open_window_neveen-sample1.wav
# 44100
# Neveen_Open_The_Window\open_window_neveen-sample2.wav
# 44100
# Neveen_Open_The_Window\open_window_neveen-sample3.wav
# 44100
# Neveen_Open_The_Window\open_window_neveen-sample4.wav
# 44100
# Neveen_Open_The_Window\open_window_neveen-sample4.wav
# Neveen_Open_The_Window.gmm
# + modeling completed for speaker: Neveen_Open_The_Window.gmm  with data point =  (995, 40)
# Nur_Close_The_Door\close_the_door_nourhan-sample0.wav
# 44100
# Nur_Close_The_Door\close_the_door_nourhan-sample1.wav
# 44100
# Nur_Close_The_Door\close_the_door_nourhan-sample2.wav
# 44100
# Nur_Close_The_Door\close_the_door_nourhan-sample3.wav
# 44100
# Nur_Close_The_Door\close_the_door_nourhan-sample4.wav
# 44100
# Nur_Close_The_Door\close_the_door_nourhan-sample4.wav
# Nur_Close_The_Door.gmm
# + modeling completed for speaker: Nur_Close_The_Door.gmm  with data point =  (995, 40)
# Nur_Close_The_Window\close_the_window_nourhan-sample0.wav
# 44100
# Nur_Close_The_Window\close_the_window_nourhan-sample1.wav
# 44100
# Nur_Close_The_Window\close_the_window_nourhan-sample2.wav
# 44100
# Nur_Close_The_Window\close_the_window_nourhan-sample3.wav
# 44100
# Nur_Close_The_Window\close_the_window_nourhan-sample4.wav
# 44100
# Nur_Close_The_Window\close_the_window_nourhan-sample4.wav
# Nur_Close_The_Window.gmm
# + modeling completed for speaker: Nur_Close_The_Window.gmm  with data point =  (995, 40)
# Nur_Open_The_Door\open_the_door_nourhan-sample0.wav
# 44100
# Nur_Open_The_Door\open_the_door_nourhan-sample1.wav
# 44100
# Nur_Open_The_Door\open_the_door_nourhan-sample2.wav
# 44100
# Nur_Open_The_Door\open_the_door_nourhan-sample3.wav
# 44100
# Nur_Open_The_Door\open_the_door_nourhan-sample4.wav
# 44100
# Nur_Open_The_Door\open_the_door_nourhan-sample4.wav
# Nur_Open_The_Door.gmm
# + modeling completed for speaker: Nur_Open_The_Door.gmm  with data point =  (995, 40)
# Nur_Open_The_Window\open_the_window_nourhan-sample0.wav
# 44100
# Nur_Open_The_Window\open_the_window_nourhan-sample1.wav
# 44100
# Nur_Open_The_Window\open_the_window_nourhan-sample2.wav
# 44100
# Nur_Open_The_Window\open_the_window_nourhan-sample3.wav
# 44100
# Nur_Open_The_Window\open_the_window_nourhan-sample4.wav
# 44100
# Nur_Open_The_Window\open_the_window_nourhan-sample4.wav
# Nur_Open_The_Window.gmm
# + modeling completed for speaker: Nur_Open_The_Window.gmm  with data point =  (995, 40)
# Omar_Close_The_Door\omar_close_door-sample0.wav
# 44100
# Omar_Close_The_Door\omar_close_door-sample1.wav
# 44100
# Omar_Close_The_Door\omar_close_door-sample2.wav
# 44100
# Omar_Close_The_Door\omar_close_door-sample3.wav
# 44100
# Omar_Close_The_Door\omar_close_door-sample4.wav
# 44100
# Omar_Close_The_Door\omar_close_door-sample4.wav
# Omar_Close_The_Door.gmm
# + modeling completed for speaker: Omar_Close_The_Door.gmm  with data point =  (995, 40)
# Omar_Close_The_Window\omar_close_window-sample0.wav
# 44100
# Omar_Close_The_Window\omar_close_window-sample1.wav
# 44100
# Omar_Close_The_Window\omar_close_window-sample2.wav
# 44100
# Omar_Close_The_Window\omar_close_window-sample3.wav
# 44100
# Omar_Close_The_Window\omar_close_window-sample4.wav
# 44100
# Omar_Close_The_Window\omar_close_window-sample4.wav
# Omar_Close_The_Window.gmm
# + modeling completed for speaker: Omar_Close_The_Window.gmm  with data point =  (995, 40)
# Omar_Open_The_Door\omar_open_door-sample0.wav
# 44100
# Omar_Open_The_Door\omar_open_door-sample1.wav
# 44100
# Omar_Open_The_Door\omar_open_door-sample2.wav
# 44100
# Omar_Open_The_Door\omar_open_door-sample3.wav
# 44100
# Omar_Open_The_Door\omar_open_door-sample4.wav
# 44100
# Omar_Open_The_Door\omar_open_door-sample4.wav
# Omar_Open_The_Door.gmm
# + modeling completed for speaker: Omar_Open_The_Door.gmm  with data point =  (995, 40)
# Omar_Open_The_Window\omar_open_window-sample0.wav
# 44100
# Omar_Open_The_Window\omar_open_window-sample1.wav
# 44100
# Omar_Open_The_Window\omar_open_window-sample2.wav
# 44100
# Omar_Open_The_Window\omar_open_window-sample3.wav
# 44100
# Omar_Open_The_Window\omar_open_window-sample4.wav
# 44100
# Omar_Open_The_Window\omar_open_window-sample4.wav
# Omar_Open_The_Window.gmm
# + modeling completed for speaker: Omar_Open_The_Window.gmm  with data point =  (995, 40)
# Salman_Close_The_Door\close-the-door-salman-sample1.wav
# 44100
# Salman_Close_The_Door\close-the-door-salman-sample2.wav
# 44100
# Salman_Close_The_Door\close-the-door-salman-sample3.wav
# 44100
# Salman_Close_The_Door\close-the-door-salman-sample4.wav
# 44100
# Salman_Close_The_Door\close-the-door-salman-sample5.wav
# 44100
# Salman_Close_The_Door\close-the-door-salman-sample5.wav
# Salman_Close_The_Door.gmm
# + modeling completed for speaker: Salman_Close_The_Door.gmm  with data point =  (995, 40)
# Salman_Close_The_Window\close-the-window-sample1.wav
# 44100
# Salman_Close_The_Window\close-the-window-sample2.wav
# 44100
# Salman_Close_The_Window\close-the-window-sample3.wav
# 44100
# Salman_Close_The_Window\close-the-window-sample4.wav
# 44100
# Salman_Close_The_Window\close-the-window-sample5.wav
# 44100
# Salman_Close_The_Window\close-the-window-sample5.wav
# Salman_Close_The_Window.gmm
# + modeling completed for speaker: Salman_Close_The_Window.gmm  with data point =  (995, 40)
# Salman_Open_The_Door\open_the_door_salman-sample1.wav
# 44100
# Salman_Open_The_Door\open_the_door_salman-sample2.wav
# 44100
# Salman_Open_The_Door\open_the_door_salman-sample3.wav
# 44100
# Salman_Open_The_Door\open_the_door_salman-sample4.wav
# 44100
# Salman_Open_The_Door\open_the_door_salman-sample5.wav
# 44100
# Salman_Open_The_Door\open_the_door_salman-sample5.wav
# Salman_Open_The_Door.gmm
# + modeling completed for speaker: Salman_Open_The_Door.gmm  with data point =  (995, 40)
# Salman_Open_The_Window\open-the-window-salman-sample0.wav
# 44100
# Salman_Open_The_Window\open-the-window-salman-sample1.wav
# 44100
# Salman_Open_The_Window\open-the-window-salman-sample2.wav
# 44100
# Salman_Open_The_Window\open-the-window-salman-sample3.wav
# 44100
# Salman_Open_The_Window\open-the-window-salman-sample4.wav
# 44100
# Salman_Open_The_Window\open-the-window-salman-sample4.wav
# Salman_Open_The_Window.gmm
# + modeling completed for speaker: Salman_Open_The_Window.gmm  with data point =  (995, 40)

# %% [markdown]
# ## Models Testing

# %%
test_model("Team_Verification")
# Out:
# Test File : Neven\close_door_neveen-sample18.wav
#
# Neveen.gmm
# -21.895330557241095
# Nurhan.gmm
# -26.680078346651644
# Omar.gmm
# -25.76609851787727
# Others_1.gmm
# -30.513643444226254
# Other_2.gmm
# -25.252634657113198
# Other_3.gmm
# -27.21934480228752
# Salman.gmm
# -26.796677704050012
# 	detected as -  Neveen
# MaxScore = -21.895330557241095
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\close_door_neveen-sample19.wav
#
# Neveen.gmm
# -20.900064840045857
# Nurhan.gmm
# -27.53337978257185
# Omar.gmm
# -27.14774480948544
# Others_1.gmm
# -31.02929591211509
# Other_2.gmm
# -25.18863885137989
# Other_3.gmm
# -27.688856395865262
# Salman.gmm
# -27.185617680296545
# 	detected as -  Neveen
# MaxScore = -20.900064840045857
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\close_door_neven.wav
#
# Neveen.gmm
# -23.983217743966684
# Nurhan.gmm
# -29.845814546358753
# Omar.gmm
# -27.042147090990287
# Others_1.gmm
# -33.235914631045084
# Other_2.gmm
# -28.281348152849652
# Other_3.gmm
# -28.42936501132126
# Salman.gmm
# -29.46174189343533
# 	detected as -  Neveen
# MaxScore = -23.983217743966684
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\close_window_neveen-sample18.wav
#
# Neveen.gmm
# -23.11743449509413
# Nurhan.gmm
# -26.28964472539232
# Omar.gmm
# -26.373655188699377
# Others_1.gmm
# -31.151624858288397
# Other_2.gmm
# -25.262876399328803
# Other_3.gmm
# -27.390717673055484
# Salman.gmm
# -28.372970353520945
# 	detected as -  Neveen
# MaxScore = -23.11743449509413
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\close_window_neveen-sample19.wav
#
# Neveen.gmm
# -24.660784431503284
# Nurhan.gmm
# -26.13261229190509
# Omar.gmm
# -25.931729012564723
# Others_1.gmm
# -31.119923449394825
# Other_2.gmm
# -25.449443063316895
# Other_3.gmm
# -27.165897866993284
# Salman.gmm
# -27.901953475606888
# 	detected as -  Neveen
# MaxScore = -24.660784431503284
# --------------------------------------------------
# Other
# ##################################################
# Test File : Neven\close_window_neven.wav
#
# Neveen.gmm
# -23.8446825033285
# Nurhan.gmm
# -27.06377394135363
# Omar.gmm
# -25.060055692745546
# Others_1.gmm
# -32.20751581292828
# Other_2.gmm
# -25.991590169635394
# Other_3.gmm
# -28.549867943036098
# Salman.gmm
# -28.961006909125263
# 	detected as -  Neveen
# MaxScore = -23.8446825033285
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\good_morning_neveen-sample18.wav
#
# Neveen.gmm
# -24.29919717277477
# Nurhan.gmm
# -25.344848987692306
# Omar.gmm
# -25.07629021878649
# Others_1.gmm
# -30.860525052706357
# Other_2.gmm
# -25.23347933083221
# Other_3.gmm
# -26.86797743921673
# Salman.gmm
# -27.714398434962167
# 	detected as -  Neveen
# MaxScore = -24.29919717277477
# --------------------------------------------------
# Other
# ##################################################
# Test File : Neven\good_morning_neveen-sample19.wav
#
# Neveen.gmm
# -22.925326150731674
# Nurhan.gmm
# -26.755096931864312
# Omar.gmm
# -25.70681234063197
# Others_1.gmm
# -30.83904721257236
# Other_2.gmm
# -25.390824500599916
# Other_3.gmm
# -26.477727125714235
# Salman.gmm
# -28.40216099906978
# 	detected as -  Neveen
# MaxScore = -22.925326150731674
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\goood_morning_neven.wav
#
# Neveen.gmm
# -25.12443091278458
# Nurhan.gmm
# -26.570308108185266
# Omar.gmm
# -25.44155651529808
# Others_1.gmm
# -32.06671847696236
# Other_2.gmm
# -26.1332115032182
# Other_3.gmm
# -27.773917224546718
# Salman.gmm
# -28.322323925230243
# 	detected as -  Neveen
# MaxScore = -25.12443091278458
# --------------------------------------------------
# Other
# ##################################################
# Test File : Neven\open_door_neven.wav
#
# Neveen.gmm
# -20.04946531302024
# Nurhan.gmm
# -26.89607021247348
# Omar.gmm
# -24.124170605619213
# Others_1.gmm
# -32.42701305384592
# Other_2.gmm
# -25.39563082111995
# Other_3.gmm
# -27.68707413655726
# Salman.gmm
# -28.847285018912356
# 	detected as -  Neveen
# MaxScore = -20.04946531302024
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\open_the_door_neven (1).wav
#
# Neveen.gmm
# -31.96712787638525
# Nurhan.gmm
# -35.133395086737536
# Omar.gmm
# -30.25268354218399
# Others_1.gmm
# -26.879329655110343
# Other_2.gmm
# -25.715728822507863
# Other_3.gmm
# -24.81505578045384
# Salman.gmm
# -32.97088719743074
# 	detected as -  Other_3
# MaxScore = -24.81505578045384
# --------------------------------------------------
# Other
# ##################################################
# Test File : Neven\open_the_door_neven (2).wav
#
# Neveen.gmm
# -21.234080528915225
# Nurhan.gmm
# -24.732876713654594
# Omar.gmm
# -23.032562842588245
# Others_1.gmm
# -30.76082227353132
# Other_2.gmm
# -23.506776293550566
# Other_3.gmm
# -25.934933837452242
# Salman.gmm
# -24.511490565039587
# 	detected as -  Neveen
# MaxScore = -21.234080528915225
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\open_window_neveen-sample18.wav
#
# Neveen.gmm
# -22.351107178924263
# Nurhan.gmm
# -27.56743300028357
# Omar.gmm
# -26.18778400178755
# Others_1.gmm
# -30.64260965673579
# Other_2.gmm
# -26.010431205976552
# Other_3.gmm
# -27.936965979183846
# Salman.gmm
# -29.284797933237183
# 	detected as -  Neveen
# MaxScore = -22.351107178924263
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\open_window_neveen-sample19.wav
#
# Neveen.gmm
# -19.502744936600955
# Nurhan.gmm
# -25.46109272585622
# Omar.gmm
# -25.056599251924975
# Others_1.gmm
# -30.69744783750731
# Other_2.gmm
# -24.510667946171324
# Other_3.gmm
# -26.78350367043804
# Salman.gmm
# -27.671731201453394
# 	detected as -  Neveen
# MaxScore = -19.502744936600955
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\open_window_neven.wav
#
# Neveen.gmm
# -26.975007507286364
# Nurhan.gmm
# -29.657115669152418
# Omar.gmm
# -27.128331530017068
# Others_1.gmm
# -33.92886058698362
# Other_2.gmm
# -28.265753376231025
# Other_3.gmm
# -30.101767741818467
# Salman.gmm
# -30.974356134145946
# 	detected as -  Neveen
# MaxScore = -26.975007507286364
# --------------------------------------------------
# Other
# ##################################################
# Test File : Nourhan\close_the_door_nourhan-sample18.wav
#
# Neveen.gmm
# -32.23064477975531
# Nurhan.gmm
# -28.973869132586128
# Omar.gmm
# -27.17829580868314
# Others_1.gmm
# -32.04864631017794
# Other_2.gmm
# -27.429958934767154
# Other_3.gmm
# -27.807158447543415
# Salman.gmm
# -29.900931645345448
# 	detected as -  Omar
# MaxScore = -27.17829580868314
# --------------------------------------------------
# Other
# ##################################################
# Test File : Nourhan\close_the_door_nourhan-sample19.wav
#
# Neveen.gmm
# -28.435055753179732
# Nurhan.gmm
# -25.91401994593682
# Omar.gmm
# -26.691609693801738
# Others_1.gmm
# -31.57083080905543
# Other_2.gmm
# -25.331660462282162
# Other_3.gmm
# -27.524238972131542
# Salman.gmm
# -27.808247037151062
# 	detected as -  Other_2
# MaxScore = -25.331660462282162
# --------------------------------------------------
# Other
# ##################################################
# Test File : Nourhan\close_the_window_nourhan-sample18.wav
#
# Neveen.gmm
# -27.269219402984003
# Nurhan.gmm
# -26.04035816746936
# Omar.gmm
# -26.084887176283935
# Others_1.gmm
# -31.054535904398648
# Other_2.gmm
# -25.67395758943247
# Other_3.gmm
# -27.361151340347575
# Salman.gmm
# -28.583522831418293
# 	detected as -  Other_2
# MaxScore = -25.67395758943247
# --------------------------------------------------
# Other
# ##################################################
# Test File : Nourhan\close_the_window_nourhan-sample19.wav
#
# Neveen.gmm
# -27.034606115165282
# Nurhan.gmm
# -25.93374663679276
# Omar.gmm
# -27.08071863749137
# Others_1.gmm
# -31.30455578808083
# Other_2.gmm
# -25.770055104193517
# Other_3.gmm
# -27.694508173766167
# Salman.gmm
# -28.7758355859352
# 	detected as -  Other_2
# MaxScore = -25.770055104193517
# --------------------------------------------------
# Other
# ##################################################
# Test File : Nourhan\good_morning_nourhan-sample18.wav
#
# Neveen.gmm
# -26.155359534252405
# Nurhan.gmm
# -24.156531041103033
# Omar.gmm
# -24.348280576610225
# Others_1.gmm
# -30.06333473299618
# Other_2.gmm
# -25.49098054569462
# Other_3.gmm
# -26.918652300842794
# Salman.gmm
# -27.128740702792243
# 	detected as -  Nurhan
# MaxScore = -24.156531041103033
# --------------------------------------------------
# Other
# ##################################################
# Test File : Nourhan\good_morning_nourhan-sample19.wav
#
# Neveen.gmm
# -26.268656556739575
# Nurhan.gmm
# -23.762661092190623
# Omar.gmm
# -25.40383473615716
# Others_1.gmm
# -29.910048181956846
# Other_2.gmm
# -24.85835668606634
# Other_3.gmm
# -26.795442357403658
# Salman.gmm
# -27.524721226967923
# 	detected as -  Nurhan
# MaxScore = -23.762661092190623
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Nourhan\open_the_door_nourhan-sample18.wav
#
# Neveen.gmm
# -29.892980146620026
# Nurhan.gmm
# -22.823395667816516
# Omar.gmm
# -26.55627049700041
# Others_1.gmm
# -28.642714419909723
# Other_2.gmm
# -24.25935601076634
# Other_3.gmm
# -26.33479087444912
# Salman.gmm
# -26.149978006176507
# 	detected as -  Nurhan
# MaxScore = -22.823395667816516
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Nourhan\open_the_door_nourhan-sample19.wav
#
# Neveen.gmm
# -25.31301600621297
# Nurhan.gmm
# -21.214951054106013
# Omar.gmm
# -24.29074358416507
# Others_1.gmm
# -30.393665026087398
# Other_2.gmm
# -25.026949461391368
# Other_3.gmm
# -26.90007243954782
# Salman.gmm
# -25.975023579346143
# 	detected as -  Nurhan
# MaxScore = -21.214951054106013
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Nourhan\open_the_window_nourhan-sample18.wav
#
# Neveen.gmm
# -26.170718559046687
# Nurhan.gmm
# -21.243906884502042
# Omar.gmm
# -24.54882411528994
# Others_1.gmm
# -27.613625660296503
# Other_2.gmm
# -25.041528378092504
# Other_3.gmm
# -26.578736355811134
# Salman.gmm
# -27.755549290390118
# 	detected as -  Nurhan
# MaxScore = -21.243906884502042
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Nourhan\open_the_window_nourhan-sample19.wav
#
# Neveen.gmm
# -25.52143048409263
# Nurhan.gmm
# -22.167013252520505
# Omar.gmm
# -25.033779363298333
# Others_1.gmm
# -29.114876925429723
# Other_2.gmm
# -24.913112878296875
# Other_3.gmm
# -26.855580525741505
# Salman.gmm
# -26.870224325272176
# 	detected as -  Nurhan
# MaxScore = -22.167013252520505
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Close_The_Door_Omar-sample18.wav
#
# Neveen.gmm
# -34.75894780282851
# Nurhan.gmm
# -32.24045103161676
# Omar.gmm
# -21.56516594060324
# Others_1.gmm
# -27.03171084074665
# Other_2.gmm
# -23.879269191348616
# Other_3.gmm
# -25.52897576673042
# Salman.gmm
# -30.613743245233515
# 	detected as -  Omar
# MaxScore = -21.56516594060324
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Close_The_Door_Omar-sample19.wav
#
# Neveen.gmm
# -35.165799193935825
# Nurhan.gmm
# -31.61137900704637
# Omar.gmm
# -20.800525648614936
# Others_1.gmm
# -27.065492635794307
# Other_2.gmm
# -23.863352594568095
# Other_3.gmm
# -25.41763298375929
# Salman.gmm
# -30.30450160953105
# 	detected as -  Omar
# MaxScore = -20.800525648614936
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Close_The_Door_Omar.wav
#
# Neveen.gmm
# -36.72366256366743
# Nurhan.gmm
# -31.563395502129453
# Omar.gmm
# -22.594223731374974
# Others_1.gmm
# -27.728077204115753
# Other_2.gmm
# -23.941013916367904
# Other_3.gmm
# -25.86737390078571
# Salman.gmm
# -29.644463607430847
# 	detected as -  Omar
# MaxScore = -22.594223731374974
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Close_The_Window_Omar-sample18.wav
#
# Neveen.gmm
# -35.995551298294444
# Nurhan.gmm
# -34.049583211233596
# Omar.gmm
# -24.49052145678916
# Others_1.gmm
# -27.120096620574543
# Other_2.gmm
# -23.86740430858832
# Other_3.gmm
# -25.48635262646165
# Salman.gmm
# -29.922574989633674
# 	detected as -  Other_2
# MaxScore = -23.86740430858832
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Close_The_Window_Omar-sample19.wav
#
# Neveen.gmm
# -34.90231981840474
# Nurhan.gmm
# -32.19985245432814
# Omar.gmm
# -19.925021141871053
# Others_1.gmm
# -26.44354600005982
# Other_2.gmm
# -23.253966385874232
# Other_3.gmm
# -24.718326155912113
# Salman.gmm
# -29.044707782084902
# 	detected as -  Omar
# MaxScore = -19.925021141871053
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Close_The_Window_Omar.wav
#
# Neveen.gmm
# -35.62864949202061
# Nurhan.gmm
# -32.52691613384003
# Omar.gmm
# -21.513125833390376
# Others_1.gmm
# -26.53350543324626
# Other_2.gmm
# -22.990582407867553
# Other_3.gmm
# -24.942207964093857
# Salman.gmm
# -28.64028733316795
# 	detected as -  Omar
# MaxScore = -21.513125833390376
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Good_Morning_Omar-sample18.wav
#
# Neveen.gmm
# -35.199515160936556
# Nurhan.gmm
# -31.219592818565086
# Omar.gmm
# -23.145221672470655
# Others_1.gmm
# -26.399053932997067
# Other_2.gmm
# -24.25373481106496
# Other_3.gmm
# -25.486774561731313
# Salman.gmm
# -29.923488131505305
# 	detected as -  Omar
# MaxScore = -23.145221672470655
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Good_Morning_Omar-sample19.wav
#
# Neveen.gmm
# -35.55606506174246
# Nurhan.gmm
# -32.03353002818854
# Omar.gmm
# -22.217421987683128
# Others_1.gmm
# -26.07859602951759
# Other_2.gmm
# -24.560686766398682
# Other_3.gmm
# -26.022526614246612
# Salman.gmm
# -29.876545433619082
# 	detected as -  Omar
# MaxScore = -22.217421987683128
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Good_Morning_Omar.wav
#
# Neveen.gmm
# -35.93427368315619
# Nurhan.gmm
# -33.703028990094694
# Omar.gmm
# -24.774803710118597
# Others_1.gmm
# -27.11370518141314
# Other_2.gmm
# -25.55360353635482
# Other_3.gmm
# -26.720899470777322
# Salman.gmm
# -31.586887033439744
# 	detected as -  Omar
# MaxScore = -24.774803710118597
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Open_The_Door_Omar-sample18.wav
#
# Neveen.gmm
# -32.12322949266343
# Nurhan.gmm
# -28.617313623223023
# Omar.gmm
# -19.257861730882414
# Others_1.gmm
# -25.861756897885375
# Other_2.gmm
# -21.550748395055177
# Other_3.gmm
# -24.263718603157667
# Salman.gmm
# -27.567263006295015
# 	detected as -  Omar
# MaxScore = -19.257861730882414
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Open_The_Door_Omar-sample19.wav
#
# Neveen.gmm
# -35.12716498618424
# Nurhan.gmm
# -30.351318135873075
# Omar.gmm
# -19.42277337608643
# Others_1.gmm
# -27.28229186064045
# Other_2.gmm
# -21.987504970693998
# Other_3.gmm
# -25.51826693624311
# Salman.gmm
# -28.593565598740817
# 	detected as -  Omar
# MaxScore = -19.42277337608643
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Open_The_Door_Omar.wav
#
# Neveen.gmm
# -33.29843254755296
# Nurhan.gmm
# -29.87172383350364
# Omar.gmm
# -18.04344576387867
# Others_1.gmm
# -26.118177551726994
# Other_2.gmm
# -20.577809463966474
# Other_3.gmm
# -23.901343876818856
# Salman.gmm
# -27.687346161140884
# 	detected as -  Omar
# MaxScore = -18.04344576387867
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Open_The_Window_Omar-sample18.wav
#
# Neveen.gmm
# -37.73043045875483
# Nurhan.gmm
# -33.38686510153013
# Omar.gmm
# -25.58644136315177
# Others_1.gmm
# -29.800955496409237
# Other_2.gmm
# -24.33609711778628
# Other_3.gmm
# -28.132229981815648
# Salman.gmm
# -30.480045236788996
# 	detected as -  Other_2
# MaxScore = -24.33609711778628
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Open_The_Window_Omar-sample19.wav
#
# Neveen.gmm
# -32.32007002168025
# Nurhan.gmm
# -28.094011160810403
# Omar.gmm
# -19.468930908549016
# Others_1.gmm
# -23.47231714748684
# Other_2.gmm
# -20.89992968514455
# Other_3.gmm
# -22.526520931313318
# Salman.gmm
# -26.060829587652393
# 	detected as -  Omar
# MaxScore = -19.468930908549016
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Open_The_Window_Omar.wav
#
# Neveen.gmm
# -35.55979212182655
# Nurhan.gmm
# -32.0643575936855
# Omar.gmm
# -20.591899538799257
# Others_1.gmm
# -26.6527477266533
# Other_2.gmm
# -23.185257997805945
# Other_3.gmm
# -25.389370944509913
# Salman.gmm
# -29.139313881159303
# 	detected as -  Omar
# MaxScore = -20.591899538799257
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : others\doha.wav
#
# Neveen.gmm
# -35.8330426238637
# Nurhan.gmm
# -36.12991215632869
# Omar.gmm
# -31.044740419201858
# Others_1.gmm
# -30.609836573935056
# Other_2.gmm
# -29.180957939323573
# Other_3.gmm
# -27.50295589596079
# Salman.gmm
# -32.6899622473314
# 	detected as -  Other_3
# MaxScore = -27.50295589596079
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\dr1.wav
#
# Neveen.gmm
# -36.980140562317686
# Nurhan.gmm
# -36.07337694731032
# Omar.gmm
# -33.66465756052901
# Others_1.gmm
# -30.035943247668904
# Other_2.gmm
# -30.762151546503507
# Other_3.gmm
# -28.231897904545665
# Salman.gmm
# -36.27028072821409
# 	detected as -  Other_3
# MaxScore = -28.231897904545665
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\dr2.wav
#
# Neveen.gmm
# -37.382213289887844
# Nurhan.gmm
# -36.67046797689123
# Omar.gmm
# -34.42052422673578
# Others_1.gmm
# -31.362464502305123
# Other_2.gmm
# -31.300563048496212
# Other_3.gmm
# -29.339202997419
# Salman.gmm
# -36.28860864663442
# 	detected as -  Other_3
# MaxScore = -29.339202997419
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\Ehab-sample10.wav
#
# Neveen.gmm
# -33.53335012777419
# Nurhan.gmm
# -32.36067356635484
# Omar.gmm
# -30.477201899120857
# Others_1.gmm
# -22.843748213252322
# Other_2.gmm
# -23.681659269545857
# Other_3.gmm
# -23.573769173123754
# Salman.gmm
# -30.948861034934673
# 	detected as -  Others_1
# MaxScore = -22.843748213252322
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : others\empty.wav
#
# Neveen.gmm
# -37.82146653064761
# Nurhan.gmm
# -35.85049296122952
# Omar.gmm
# -32.0806990625889
# Others_1.gmm
# -36.24548258182869
# Other_2.gmm
# -30.7107785020331
# Other_3.gmm
# -32.877898190152465
# Salman.gmm
# -34.47830011565623
# 	detected as -  Other_2
# MaxScore = -30.7107785020331
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\neven.wav
#
# Neveen.gmm
# -34.99990315198067
# Nurhan.gmm
# -37.61780716314737
# Omar.gmm
# -34.7946112559676
# Others_1.gmm
# -29.98736623271449
# Other_2.gmm
# -30.431717600379773
# Other_3.gmm
# -28.968713664073164
# Salman.gmm
# -37.1001749680011
# 	detected as -  Other_3
# MaxScore = -28.968713664073164
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\nevveeen.wav
#
# Neveen.gmm
# -34.97367972754374
# Nurhan.gmm
# -37.51591697361548
# Omar.gmm
# -33.47016032798524
# Others_1.gmm
# -30.0755018024353
# Other_2.gmm
# -28.73126399532112
# Other_3.gmm
# -28.45390541998077
# Salman.gmm
# -36.62147794645837
# 	detected as -  Other_3
# MaxScore = -28.45390541998077
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\nurhaan.wav
#
# Neveen.gmm
# -24.27305240747765
# Nurhan.gmm
# -25.586287757276853
# Omar.gmm
# -23.934017014105606
# Others_1.gmm
# -30.82602343316586
# Other_2.gmm
# -23.086554359931046
# Other_3.gmm
# -26.780592770583883
# Salman.gmm
# -26.19471314105615
# 	detected as -  Other_2
# MaxScore = -23.086554359931046
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : others\nurhan.wav
#
# Neveen.gmm
# -39.428037866452286
# Nurhan.gmm
# -40.475712953291094
# Omar.gmm
# -32.65705295471995
# Others_1.gmm
# -34.249114832044356
# Other_2.gmm
# -30.045544364687558
# Other_3.gmm
# -30.39119105541977
# Salman.gmm
# -37.084399584093376
# 	detected as -  Other_2
# MaxScore = -30.045544364687558
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\omar.wav
#
# Neveen.gmm
# -30.521669295054462
# Nurhan.gmm
# -28.713677878139702
# Omar.gmm
# -24.86988024210506
# Others_1.gmm
# -32.343040009561705
# Other_2.gmm
# -23.88268708674035
# Other_3.gmm
# -28.799307251157256
# Salman.gmm
# -26.436886425658145
# 	detected as -  Other_2
# MaxScore = -23.88268708674035
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : others\omarTest (1).wav
#
# Neveen.gmm
# -33.62166992460895
# Nurhan.gmm
# -28.347503944839563
# Omar.gmm
# -24.23217350831003
# Others_1.gmm
# -26.594687828985162
# Other_2.gmm
# -22.816170760072623
# Other_3.gmm
# -25.075805473066904
# Salman.gmm
# -28.467292514245646
# 	detected as -  Other_2
# MaxScore = -22.816170760072623
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : others\omarTest (2).wav
#
# Neveen.gmm
# -28.280611960265958
# Nurhan.gmm
# -24.088299581510256
# Omar.gmm
# -22.11709542407549
# Others_1.gmm
# -27.320860851045403
# Other_2.gmm
# -22.359694511981434
# Other_3.gmm
# -25.308351616053983
# Salman.gmm
# -25.86977095576081
# 	detected as -  Omar
# MaxScore = -22.11709542407549
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : others\omarTest (3).wav
#
# Neveen.gmm
# -28.365509474913384
# Nurhan.gmm
# -28.455838819806864
# Omar.gmm
# -23.85724469531953
# Others_1.gmm
# -33.40815755958188
# Other_2.gmm
# -25.197754245020203
# Other_3.gmm
# -28.41568406190311
# Salman.gmm
# -28.386108641983792
# 	detected as -  Omar
# MaxScore = -23.85724469531953
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : others\omar_close_door.wav
#
# Neveen.gmm
# -27.70304910430293
# Nurhan.gmm
# -27.468764468022062
# Omar.gmm
# -23.432476841732836
# Others_1.gmm
# -32.18617573868334
# Other_2.gmm
# -24.92093631474949
# Other_3.gmm
# -28.042638945111914
# Salman.gmm
# -26.775250482176084
# 	detected as -  Omar
# MaxScore = -23.432476841732836
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : others\omar_close_door2.wav
#
# Neveen.gmm
# -34.0848467040056
# Nurhan.gmm
# -30.814404327194765
# Omar.gmm
# -27.762589358791892
# Others_1.gmm
# -33.01929800192388
# Other_2.gmm
# -27.454567894345974
# Other_3.gmm
# -30.47423605748195
# Salman.gmm
# -29.655551702272327
# 	detected as -  Other_2
# MaxScore = -27.454567894345974
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\omar_open_door.wav
#
# Neveen.gmm
# -34.60825221483532
# Nurhan.gmm
# -29.97274423555582
# Omar.gmm
# -25.914924546257616
# Others_1.gmm
# -30.362308023064113
# Other_2.gmm
# -24.54164452099819
# Other_3.gmm
# -27.992438517471065
# Salman.gmm
# -28.60274200221024
# 	detected as -  Other_2
# MaxScore = -24.54164452099819
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\omar_open_window.wav
#
# Neveen.gmm
# -34.12500706254733
# Nurhan.gmm
# -30.228177249572482
# Omar.gmm
# -26.788175701872504
# Others_1.gmm
# -30.56622629906074
# Other_2.gmm
# -26.3157366828235
# Other_3.gmm
# -28.69828878370526
# Salman.gmm
# -29.199711387155094
# 	detected as -  Other_2
# MaxScore = -26.3157366828235
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\otthher.wav
#
# Neveen.gmm
# -29.68524948945182
# Nurhan.gmm
# -30.747252845405757
# Omar.gmm
# -27.482921763349562
# Others_1.gmm
# -33.89536578554378
# Other_2.gmm
# -26.713892024137834
# Other_3.gmm
# -30.634778575730483
# Salman.gmm
# -30.097500126823196
# 	detected as -  Other_2
# MaxScore = -26.713892024137834
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\Salman.wav
#
# Neveen.gmm
# -28.306353558384387
# Nurhan.gmm
# -30.355367812303754
# Omar.gmm
# -25.369275755834362
# Others_1.gmm
# -32.534773348498256
# Other_2.gmm
# -25.086881946508786
# Other_3.gmm
# -29.181638027964514
# Salman.gmm
# -24.735142579410528
# 	detected as -  Salman
# MaxScore = -24.735142579410528
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\sample.wav
#
# Neveen.gmm
# -31.41677757935444
# Nurhan.gmm
# -26.86751225231821
# Omar.gmm
# -24.957104348842783
# Others_1.gmm
# -30.530166788042276
# Other_2.gmm
# -21.4203760009899
# Other_3.gmm
# -26.087171067313786
# Salman.gmm
# -25.68875982521425
# 	detected as -  Other_2
# MaxScore = -21.4203760009899
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : others\sarta.wav
#
# Neveen.gmm
# -30.378114532194157
# Nurhan.gmm
# -29.801772073089438
# Omar.gmm
# -26.89449633789548
# Others_1.gmm
# -33.36725701181809
# Other_2.gmm
# -26.913261295871788
# Other_3.gmm
# -30.734126834852024
# Salman.gmm
# -30.47228683444725
# 	detected as -  Omar
# MaxScore = -26.89449633789548
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\Sherif-sample9.wav
#
# Neveen.gmm
# -36.5773163883923
# Nurhan.gmm
# -36.5821154598338
# Omar.gmm
# -29.366503584483354
# Others_1.gmm
# -31.230078159477124
# Other_2.gmm
# -26.027860621898355
# Other_3.gmm
# -25.457351674555106
# Salman.gmm
# -32.63934645363153
# 	detected as -  Other_3
# MaxScore = -25.457351674555106
# --------------------------------------------------
# Other
# ##################################################
# Test File : Salman\close-the-door-salman-sample18.wav
#
# Neveen.gmm
# -28.98147367049409
# Nurhan.gmm
# -27.713173644881
# Omar.gmm
# -24.512815875132272
# Others_1.gmm
# -31.74141760947703
# Other_2.gmm
# -24.547312916088945
# Other_3.gmm
# -28.34293505087336
# Salman.gmm
# -22.928993158878338
# 	detected as -  Salman
# MaxScore = -22.928993158878338
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\close-the-door-salman-sample19.wav
#
# Neveen.gmm
# -27.886966894757244
# Nurhan.gmm
# -27.30327146512187
# Omar.gmm
# -24.409019677130363
# Others_1.gmm
# -32.08558180257435
# Other_2.gmm
# -25.182053154204564
# Other_3.gmm
# -28.61228310005759
# Salman.gmm
# -22.53024918337141
# 	detected as -  Salman
# MaxScore = -22.53024918337141
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\close-the-window-sample18.wav
#
# Neveen.gmm
# -32.90951483132071
# Nurhan.gmm
# -29.667657797812428
# Omar.gmm
# -27.086702826242064
# Others_1.gmm
# -32.68944932363888
# Other_2.gmm
# -25.21084261225411
# Other_3.gmm
# -28.740956859616038
# Salman.gmm
# -23.95508520964376
# 	detected as -  Salman
# MaxScore = -23.95508520964376
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\close-the-window-sample19.wav
#
# Neveen.gmm
# -27.598325653721457
# Nurhan.gmm
# -27.94638100468049
# Omar.gmm
# -24.793899605908322
# Others_1.gmm
# -31.31058304067993
# Other_2.gmm
# -23.871711000390988
# Other_3.gmm
# -27.62477180355895
# Salman.gmm
# -23.200559420546778
# 	detected as -  Salman
# MaxScore = -23.200559420546778
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\goodmorning-salman-sample18.wav
#
# Neveen.gmm
# -30.08423556732592
# Nurhan.gmm
# -25.94569036555043
# Omar.gmm
# -23.627196018346563
# Others_1.gmm
# -31.02096077771942
# Other_2.gmm
# -22.72621657917659
# Other_3.gmm
# -26.372818897354318
# Salman.gmm
# -24.600279003518793
# 	detected as -  Other_2
# MaxScore = -22.72621657917659
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\goodmorning-salman-sample19.wav
#
# Neveen.gmm
# -28.90749178425195
# Nurhan.gmm
# -26.410906139346988
# Omar.gmm
# -24.280529316205097
# Others_1.gmm
# -31.086176029327557
# Other_2.gmm
# -23.945326825478727
# Other_3.gmm
# -26.953244941982167
# Salman.gmm
# -25.704054088525194
# 	detected as -  Other_2
# MaxScore = -23.945326825478727
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\open-the-window-salman-sample18.wav
#
# Neveen.gmm
# -31.838933123964562
# Nurhan.gmm
# -27.737720474358625
# Omar.gmm
# -26.22943851747178
# Others_1.gmm
# -30.63171633401103
# Other_2.gmm
# -24.170962176346862
# Other_3.gmm
# -27.209208866990895
# Salman.gmm
# -21.650128948000777
# 	detected as -  Salman
# MaxScore = -21.650128948000777
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\open-the-window-salman-sample19.wav
#
# Neveen.gmm
# -30.381526653060796
# Nurhan.gmm
# -26.91916145457177
# Omar.gmm
# -25.213768064390436
# Others_1.gmm
# -31.04797830058475
# Other_2.gmm
# -23.2969855516822
# Other_3.gmm
# -26.886849715956476
# Salman.gmm
# -21.09355637766908
# 	detected as -  Salman
# MaxScore = -21.09355637766908
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\open_the_door_salman-sample18.wav
#
# Neveen.gmm
# -24.692949334704327
# Nurhan.gmm
# -23.966381723698582
# Omar.gmm
# -22.367275636782153
# Others_1.gmm
# -29.562542774419473
# Other_2.gmm
# -23.470016383006307
# Other_3.gmm
# -26.211826052581653
# Salman.gmm
# -18.44304921396943
# 	detected as -  Salman
# MaxScore = -18.44304921396943
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\open_the_door_salman-sample19.wav
#
# Neveen.gmm
# -23.403753203964733
# Nurhan.gmm
# -25.065420499488074
# Omar.gmm
# -23.290487806793237
# Others_1.gmm
# -28.67890611796829
# Other_2.gmm
# -23.033938073081416
# Other_3.gmm
# -25.454402659116234
# Salman.gmm
# -19.600747963873125
# 	detected as -  Salman
# MaxScore = -19.600747963873125
# --------------------------------------------------
# Accepted
# ##################################################

# %%
test_model("Sentence_Verification")
# Out:
# Test File : Neven\close_door_neveen-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -19.67967009135858
# Neveen_Close_The_Window.gmm
# -22.013328369893255
# Neveen_Open_The_Door.gmm
# -22.566884461253018
# Neveen_Open_The_Window.gmm
# -22.924086120967488
# Nur_Close_The_Door.gmm
# -29.477156717862396
# Nur_Close_The_Window.gmm
# -27.71550844570354
# Nur_Open_The_Door.gmm
# -26.287227143952865
# Nur_Open_The_Window.gmm
# -25.551354353596544
# Omar_Close_The_Door.gmm
# -30.18744020419865
# Omar_Close_The_Window.gmm
# -26.615646857030537
# Omar_Open_The_Door.gmm
# -25.899947603640705
# Omar_Open_The_Window.gmm
# -27.10388047731759
# Salman_Close_The_Door.gmm
# -27.412418739090818
# Salman_Close_The_Window.gmm
# -26.107234306197718
# Salman_Open_The_Door.gmm
# -27.425213380609197
# Salman_Open_The_Window.gmm
# -30.290168827082482
# 	detected as -  Neveen_Close_The_Door
# MaxScore = -19.67967009135858
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\close_door_neveen-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -19.27057513406006
# Neveen_Close_The_Window.gmm
# -22.48281780025996
# Neveen_Open_The_Door.gmm
# -21.28942417129527
# Neveen_Open_The_Window.gmm
# -23.48984077691319
# Nur_Close_The_Door.gmm
# -29.431250124917153
# Nur_Close_The_Window.gmm
# -27.770836565536467
# Nur_Open_The_Door.gmm
# -26.690542600373956
# Nur_Open_The_Window.gmm
# -26.76291491610842
# Omar_Close_The_Door.gmm
# -30.507935116581983
# Omar_Close_The_Window.gmm
# -27.35867056396733
# Omar_Open_The_Door.gmm
# -27.758830437722125
# Omar_Open_The_Window.gmm
# -27.726290231456314
# Salman_Close_The_Door.gmm
# -28.42137592406582
# Salman_Close_The_Window.gmm
# -26.88521107928765
# Salman_Open_The_Door.gmm
# -27.186529213640295
# Salman_Open_The_Window.gmm
# -31.29360482075422
# 	detected as -  Neveen_Close_The_Door
# MaxScore = -19.27057513406006
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\close_door_neven.wav
#
# Neveen_Close_The_Door.gmm
# -23.35401271793391
# Neveen_Close_The_Window.gmm
# -27.42483320461735
# Neveen_Open_The_Door.gmm
# -24.205768519983568
# Neveen_Open_The_Window.gmm
# -28.275463516894778
# Nur_Close_The_Door.gmm
# -31.69276022433278
# Nur_Close_The_Window.gmm
# -30.772043004002864
# Nur_Open_The_Door.gmm
# -28.414437999720143
# Nur_Open_The_Window.gmm
# -30.42966077257544
# Omar_Close_The_Door.gmm
# -29.220528412050765
# Omar_Close_The_Window.gmm
# -26.290664574824056
# Omar_Open_The_Door.gmm
# -27.348603846412225
# Omar_Open_The_Window.gmm
# -27.637500632071674
# Salman_Close_The_Door.gmm
# -30.984360817464044
# Salman_Close_The_Window.gmm
# -29.595240474197897
# Salman_Open_The_Door.gmm
# -30.1087221050751
# Salman_Open_The_Window.gmm
# -34.54076025207298
# 	detected as -  Neveen_Close_The_Door
# MaxScore = -23.35401271793391
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\close_window_neveen-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -22.00416856994697
# Neveen_Close_The_Window.gmm
# -19.534506445963984
# Neveen_Open_The_Door.gmm
# -23.660279323543932
# Neveen_Open_The_Window.gmm
# -20.81955921884863
# Nur_Close_The_Door.gmm
# -29.301804516651067
# Nur_Close_The_Window.gmm
# -27.247857438079148
# Nur_Open_The_Door.gmm
# -25.859518739976526
# Nur_Open_The_Window.gmm
# -27.007554293213676
# Omar_Close_The_Door.gmm
# -35.50999911009863
# Omar_Close_The_Window.gmm
# -28.05518470674539
# Omar_Open_The_Door.gmm
# -26.683977554958503
# Omar_Open_The_Window.gmm
# -27.402880935282138
# Salman_Close_The_Door.gmm
# -29.811076437178475
# Salman_Close_The_Window.gmm
# -26.86509735571693
# Salman_Open_The_Door.gmm
# -29.072319757042298
# Salman_Open_The_Window.gmm
# -31.565272572722073
# 	detected as -  Neveen_Close_The_Window
# MaxScore = -19.534506445963984
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\close_window_neveen-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -23.56906323281835
# Neveen_Close_The_Window.gmm
# -21.878975855564132
# Neveen_Open_The_Door.gmm
# -24.532167280166775
# Neveen_Open_The_Window.gmm
# -22.944029583337954
# Nur_Close_The_Door.gmm
# -28.27068552604498
# Nur_Close_The_Window.gmm
# -26.987362243941156
# Nur_Open_The_Door.gmm
# -26.25912619917154
# Nur_Open_The_Window.gmm
# -27.596157601997284
# Omar_Close_The_Door.gmm
# -36.29420431606847
# Omar_Close_The_Window.gmm
# -28.569526802478883
# Omar_Open_The_Door.gmm
# -26.4222999877808
# Omar_Open_The_Window.gmm
# -27.339495162959373
# Salman_Close_The_Door.gmm
# -30.28694884063142
# Salman_Close_The_Window.gmm
# -27.280713369046406
# Salman_Open_The_Door.gmm
# -28.614042924580726
# Salman_Open_The_Window.gmm
# -30.890857660756296
# 	detected as -  Neveen_Close_The_Window
# MaxScore = -21.878975855564132
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\close_window_neven.wav
#
# Neveen_Close_The_Door.gmm
# -24.484609435194436
# Neveen_Close_The_Window.gmm
# -26.266198123314197
# Neveen_Open_The_Door.gmm
# -23.75349950970679
# Neveen_Open_The_Window.gmm
# -24.537923902692267
# Nur_Close_The_Door.gmm
# -32.13571901671131
# Nur_Close_The_Window.gmm
# -30.87231598278594
# Nur_Open_The_Door.gmm
# -26.00864042501909
# Nur_Open_The_Window.gmm
# -26.85531750375849
# Omar_Close_The_Door.gmm
# -26.193707213920646
# Omar_Close_The_Window.gmm
# -27.698945893680722
# Omar_Open_The_Door.gmm
# -25.20623738084975
# Omar_Open_The_Window.gmm
# -25.744317176902864
# Salman_Close_The_Door.gmm
# -30.930227884974553
# Salman_Close_The_Window.gmm
# -27.358536486502572
# Salman_Open_The_Door.gmm
# -29.267036719473417
# Salman_Open_The_Window.gmm
# -30.80646291737395
# 	detected as -  Neveen_Open_The_Door
# MaxScore = -23.75349950970679
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\good_morning_neveen-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -25.684669989791793
# Neveen_Close_The_Window.gmm
# -26.736105400104112
# Neveen_Open_The_Door.gmm
# -23.41354034481051
# Neveen_Open_The_Window.gmm
# -24.70508406031261
# Nur_Close_The_Door.gmm
# -28.13715383301724
# Nur_Close_The_Window.gmm
# -30.017686670166945
# Nur_Open_The_Door.gmm
# -24.38379659159876
# Nur_Open_The_Window.gmm
# -28.334677509869035
# Omar_Close_The_Door.gmm
# -27.884376432135625
# Omar_Close_The_Window.gmm
# -26.71244505367407
# Omar_Open_The_Door.gmm
# -26.097029907712216
# Omar_Open_The_Window.gmm
# -26.473637309742774
# Salman_Close_The_Door.gmm
# -28.920142144323492
# Salman_Close_The_Window.gmm
# -26.294094867557096
# Salman_Open_The_Door.gmm
# -28.032901078215712
# Salman_Open_The_Window.gmm
# -30.456712064449786
# 	detected as -  Neveen_Open_The_Door
# MaxScore = -23.41354034481051
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\good_morning_neveen-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -24.587278103839505
# Neveen_Close_The_Window.gmm
# -23.53972594656952
# Neveen_Open_The_Door.gmm
# -23.461291565216946
# Neveen_Open_The_Window.gmm
# -21.43395314533942
# Nur_Close_The_Door.gmm
# -27.141092280274755
# Nur_Close_The_Window.gmm
# -27.600727187565177
# Nur_Open_The_Door.gmm
# -26.401515541880016
# Nur_Open_The_Window.gmm
# -29.162639741788567
# Omar_Close_The_Door.gmm
# -36.16864170789953
# Omar_Close_The_Window.gmm
# -25.87949204994369
# Omar_Open_The_Door.gmm
# -26.321149889199944
# Omar_Open_The_Window.gmm
# -26.789608730415573
# Salman_Close_The_Door.gmm
# -29.10524840300082
# Salman_Close_The_Window.gmm
# -26.848601934047792
# Salman_Open_The_Door.gmm
# -27.99914542564248
# Salman_Open_The_Window.gmm
# -30.701531756876996
# 	detected as -  Neveen_Open_The_Window
# MaxScore = -21.43395314533942
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\goood_morning_neven.wav
#
# Neveen_Close_The_Door.gmm
# -25.69007610055618
# Neveen_Close_The_Window.gmm
# -28.971323145740776
# Neveen_Open_The_Door.gmm
# -24.8215271047578
# Neveen_Open_The_Window.gmm
# -27.777236242250975
# Nur_Close_The_Door.gmm
# -31.992615930196227
# Nur_Close_The_Window.gmm
# -31.006396863589107
# Nur_Open_The_Door.gmm
# -25.751140653612577
# Nur_Open_The_Window.gmm
# -27.589604015164554
# Omar_Close_The_Door.gmm
# -27.256433808839052
# Omar_Close_The_Window.gmm
# -26.881704319834792
# Omar_Open_The_Door.gmm
# -25.97982588220456
# Omar_Open_The_Window.gmm
# -25.94863924274456
# Salman_Close_The_Door.gmm
# -31.25072065451314
# Salman_Close_The_Window.gmm
# -27.417812177783485
# Salman_Open_The_Door.gmm
# -29.13400949612815
# Salman_Open_The_Window.gmm
# -30.938994380641955
# 	detected as -  Neveen_Open_The_Door
# MaxScore = -24.8215271047578
# --------------------------------------------------
# Other
# ##################################################
# Test File : Neven\open_door_neven.wav
#
# Neveen_Close_The_Door.gmm
# -22.920135217474638
# Neveen_Close_The_Window.gmm
# -26.946567941662654
# Neveen_Open_The_Door.gmm
# -19.604495929940516
# Neveen_Open_The_Window.gmm
# -23.51429734072885
# Nur_Close_The_Door.gmm
# -32.31234523688922
# Nur_Close_The_Window.gmm
# -31.353809439712343
# Nur_Open_The_Door.gmm
# -25.997661931973752
# Nur_Open_The_Window.gmm
# -27.136559496522235
# Omar_Close_The_Door.gmm
# -26.003734136280826
# Omar_Close_The_Window.gmm
# -24.73922094060658
# Omar_Open_The_Door.gmm
# -23.958862185764318
# Omar_Open_The_Window.gmm
# -24.63760820215554
# Salman_Close_The_Door.gmm
# -31.176835346473542
# Salman_Close_The_Window.gmm
# -27.72274624066136
# Salman_Open_The_Door.gmm
# -28.945693927959173
# Salman_Open_The_Window.gmm
# -32.3205609825526
# 	detected as -  Neveen_Open_The_Door
# MaxScore = -19.604495929940516
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\open_the_door_neven (1).wav
#
# Neveen_Close_The_Door.gmm
# -30.427942115323127
# Neveen_Close_The_Window.gmm
# -31.315771621214292
# Neveen_Open_The_Door.gmm
# -31.224770589465027
# Neveen_Open_The_Window.gmm
# -33.28512150473849
# Nur_Close_The_Door.gmm
# -37.05526545637823
# Nur_Close_The_Window.gmm
# -31.42476140375558
# Nur_Open_The_Door.gmm
# -33.97482153457553
# Nur_Open_The_Window.gmm
# -31.2326219186237
# Omar_Close_The_Door.gmm
# -38.68204078201351
# Omar_Close_The_Window.gmm
# -34.93810103427721
# Omar_Open_The_Door.gmm
# -35.16266168573427
# Omar_Open_The_Window.gmm
# -33.82826760689769
# Salman_Close_The_Door.gmm
# -34.99083067385673
# Salman_Close_The_Window.gmm
# -31.436771496132554
# Salman_Open_The_Door.gmm
# -32.724997226506844
# Salman_Open_The_Window.gmm
# -36.71531614086954
# 	detected as -  Neveen_Close_The_Door
# MaxScore = -30.427942115323127
# --------------------------------------------------
# Other
# ##################################################
# Test File : Neven\open_the_door_neven (2).wav
#
# Neveen_Close_The_Door.gmm
# -21.847227465140175
# Neveen_Close_The_Window.gmm
# -23.377601532740183
# Neveen_Open_The_Door.gmm
# -21.0745544402309
# Neveen_Open_The_Window.gmm
# -23.106546789236756
# Nur_Close_The_Door.gmm
# -28.445333940126716
# Nur_Close_The_Window.gmm
# -26.895161248154707
# Nur_Open_The_Door.gmm
# -24.32419072694878
# Nur_Open_The_Window.gmm
# -22.020466484515996
# Omar_Close_The_Door.gmm
# -29.506969664836905
# Omar_Close_The_Window.gmm
# -25.359631959638502
# Omar_Open_The_Door.gmm
# -23.28623725924576
# Omar_Open_The_Window.gmm
# -24.184528550961147
# Salman_Close_The_Door.gmm
# -26.734070807302405
# Salman_Close_The_Window.gmm
# -25.177835609555522
# Salman_Open_The_Door.gmm
# -24.871402003099252
# Salman_Open_The_Window.gmm
# -25.395912485569202
# 	detected as -  Neveen_Open_The_Door
# MaxScore = -21.0745544402309
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\open_window_neveen-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -25.021550491059525
# Neveen_Close_The_Window.gmm
# -23.040780837657124
# Neveen_Open_The_Door.gmm
# -22.993215796810272
# Neveen_Open_The_Window.gmm
# -19.154055287310644
# Nur_Close_The_Door.gmm
# -29.86684651483081
# Nur_Close_The_Window.gmm
# -29.161980748230825
# Nur_Open_The_Door.gmm
# -26.597365978780587
# Nur_Open_The_Window.gmm
# -26.99721397234935
# Omar_Close_The_Door.gmm
# -33.514824963324976
# Omar_Close_The_Window.gmm
# -27.508306105612704
# Omar_Open_The_Door.gmm
# -26.57726680748284
# Omar_Open_The_Window.gmm
# -27.45402630717058
# Salman_Close_The_Door.gmm
# -31.29187575104492
# Salman_Close_The_Window.gmm
# -28.58884002526216
# Salman_Open_The_Door.gmm
# -29.120627892457613
# Salman_Open_The_Window.gmm
# -32.09085644939884
# 	detected as -  Neveen_Open_The_Window
# MaxScore = -19.154055287310644
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\open_window_neveen-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -22.89031017003423
# Neveen_Close_The_Window.gmm
# -22.889449542344845
# Neveen_Open_The_Door.gmm
# -19.96456064272461
# Neveen_Open_The_Window.gmm
# -18.887176809451613
# Nur_Close_The_Door.gmm
# -28.79590876220171
# Nur_Close_The_Window.gmm
# -28.99762312822066
# Nur_Open_The_Door.gmm
# -24.36156623861391
# Nur_Open_The_Window.gmm
# -25.611887499133243
# Omar_Close_The_Door.gmm
# -27.619347063747504
# Omar_Close_The_Window.gmm
# -25.969160735515445
# Omar_Open_The_Door.gmm
# -25.085642714464356
# Omar_Open_The_Window.gmm
# -25.497820480837248
# Salman_Close_The_Door.gmm
# -29.415973633716447
# Salman_Close_The_Window.gmm
# -25.589881379786
# Salman_Open_The_Door.gmm
# -27.951412935163418
# Salman_Open_The_Window.gmm
# -29.88555197328668
# 	detected as -  Neveen_Open_The_Window
# MaxScore = -18.887176809451613
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Neven\open_window_neven.wav
#
# Neveen_Close_The_Door.gmm
# -28.98948989769324
# Neveen_Close_The_Window.gmm
# -31.648512572881145
# Neveen_Open_The_Door.gmm
# -26.639878997812335
# Neveen_Open_The_Window.gmm
# -28.284706252840333
# Nur_Close_The_Door.gmm
# -34.379335074514664
# Nur_Close_The_Window.gmm
# -33.827978883770896
# Nur_Open_The_Door.gmm
# -28.25509089345819
# Nur_Open_The_Window.gmm
# -29.926331278200422
# Omar_Close_The_Door.gmm
# -30.058217408080434
# Omar_Close_The_Window.gmm
# -27.68674693707185
# Omar_Open_The_Door.gmm
# -27.54835925021349
# Omar_Open_The_Window.gmm
# -28.45704516902489
# Salman_Close_The_Door.gmm
# -32.751147637071554
# Salman_Close_The_Window.gmm
# -30.192632191075276
# Salman_Open_The_Door.gmm
# -31.094921796163728
# Salman_Open_The_Window.gmm
# -34.391257496277085
# 	detected as -  Neveen_Open_The_Door
# MaxScore = -26.639878997812335
# --------------------------------------------------
# Other
# ##################################################
# Test File : Nourhan\close_the_door_nourhan-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -30.89681995987481
# Neveen_Close_The_Window.gmm
# -31.238649286776884
# Neveen_Open_The_Door.gmm
# -31.60658884084993
# Neveen_Open_The_Window.gmm
# -32.20892947985506
# Nur_Close_The_Door.gmm
# -25.23217824191657
# Nur_Close_The_Window.gmm
# -26.756999286416974
# Nur_Open_The_Door.gmm
# -28.854176231332257
# Nur_Open_The_Window.gmm
# -28.179500086319642
# Omar_Close_The_Door.gmm
# -37.72943389475069
# Omar_Close_The_Window.gmm
# -30.24155443197539
# Omar_Open_The_Door.gmm
# -28.900878728065663
# Omar_Open_The_Window.gmm
# -30.987259381742437
# Salman_Close_The_Door.gmm
# -31.061607092477434
# Salman_Close_The_Window.gmm
# -30.535429497157534
# Salman_Open_The_Door.gmm
# -30.632908789233863
# Salman_Open_The_Window.gmm
# -35.637500831672796
# 	detected as -  Nur_Close_The_Door
# MaxScore = -25.23217824191657
# --------------------------------------------------
# Other
# ##################################################
# Test File : Nourhan\close_the_door_nourhan-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -27.96168101388597
# Neveen_Close_The_Window.gmm
# -28.95880052794878
# Neveen_Open_The_Door.gmm
# -27.838022498243504
# Neveen_Open_The_Window.gmm
# -29.6172914081658
# Nur_Close_The_Door.gmm
# -23.406945542194325
# Nur_Close_The_Window.gmm
# -25.23451405230443
# Nur_Open_The_Door.gmm
# -25.687915806014306
# Nur_Open_The_Window.gmm
# -28.254618458890977
# Omar_Close_The_Door.gmm
# -36.10201945160366
# Omar_Close_The_Window.gmm
# -29.37680174785697
# Omar_Open_The_Door.gmm
# -27.724221011337555
# Omar_Open_The_Window.gmm
# -28.94919531532033
# Salman_Close_The_Door.gmm
# -29.202744968207377
# Salman_Close_The_Window.gmm
# -28.033345086069797
# Salman_Open_The_Door.gmm
# -28.612672980412945
# Salman_Open_The_Window.gmm
# -31.250151935914907
# 	detected as -  Nur_Close_The_Door
# MaxScore = -23.406945542194325
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Nourhan\close_the_window_nourhan-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -26.852702296229086
# Neveen_Close_The_Window.gmm
# -27.598016112734847
# Neveen_Open_The_Door.gmm
# -27.414689790480548
# Neveen_Open_The_Window.gmm
# -28.71923406205793
# Nur_Close_The_Door.gmm
# -25.162383045711
# Nur_Close_The_Window.gmm
# -19.65310297158556
# Nur_Open_The_Door.gmm
# -25.721589918431846
# Nur_Open_The_Window.gmm
# -24.232871410375402
# Omar_Close_The_Door.gmm
# -37.03966051276798
# Omar_Close_The_Window.gmm
# -29.02827895973838
# Omar_Open_The_Door.gmm
# -27.47471727440286
# Omar_Open_The_Window.gmm
# -29.26671581422033
# Salman_Close_The_Door.gmm
# -28.77582443500803
# Salman_Close_The_Window.gmm
# -27.707241411862828
# Salman_Open_The_Door.gmm
# -30.061189868162906
# Salman_Open_The_Window.gmm
# -30.507809591377253
# 	detected as -  Nur_Close_The_Window
# MaxScore = -19.65310297158556
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Nourhan\close_the_window_nourhan-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -25.75603573379124
# Neveen_Close_The_Window.gmm
# -26.756520059575884
# Neveen_Open_The_Door.gmm
# -26.750006209687236
# Neveen_Open_The_Window.gmm
# -27.85136180439226
# Nur_Close_The_Door.gmm
# -25.301780546535458
# Nur_Close_The_Window.gmm
# -19.15238355036187
# Nur_Open_The_Door.gmm
# -25.087979662092533
# Nur_Open_The_Window.gmm
# -23.97526038623671
# Omar_Close_The_Door.gmm
# -37.582767185959284
# Omar_Close_The_Window.gmm
# -30.196609178560397
# Omar_Open_The_Door.gmm
# -28.57319833885173
# Omar_Open_The_Window.gmm
# -30.07844707755741
# Salman_Close_The_Door.gmm
# -30.17650447418173
# Salman_Close_The_Window.gmm
# -27.92492187206326
# Salman_Open_The_Door.gmm
# -30.54616847685196
# Salman_Open_The_Window.gmm
# -31.004784379554266
# 	detected as -  Nur_Close_The_Window
# MaxScore = -19.15238355036187
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Nourhan\good_morning_nourhan-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -26.859637474766476
# Neveen_Close_The_Window.gmm
# -28.206761811861906
# Neveen_Open_The_Door.gmm
# -26.150330683234515
# Neveen_Open_The_Window.gmm
# -27.21889374699303
# Nur_Close_The_Door.gmm
# -26.9091777806723
# Nur_Close_The_Window.gmm
# -25.506486946486074
# Nur_Open_The_Door.gmm
# -23.907256890322714
# Nur_Open_The_Window.gmm
# -23.92754265203862
# Omar_Close_The_Door.gmm
# -32.577485543504004
# Omar_Close_The_Window.gmm
# -27.058998453071275
# Omar_Open_The_Door.gmm
# -24.61399245826593
# Omar_Open_The_Window.gmm
# -26.973710114090125
# Salman_Close_The_Door.gmm
# -29.086057119070826
# Salman_Close_The_Window.gmm
# -26.32105030365816
# Salman_Open_The_Door.gmm
# -28.461599305903647
# Salman_Open_The_Window.gmm
# -29.86412477352407
# 	detected as -  Nur_Open_The_Door
# MaxScore = -23.907256890322714
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Nourhan\good_morning_nourhan-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -27.59260945113724
# Neveen_Close_The_Window.gmm
# -27.876930439491332
# Neveen_Open_The_Door.gmm
# -26.377570083803853
# Neveen_Open_The_Window.gmm
# -27.282133825601896
# Nur_Close_The_Door.gmm
# -25.144738840908147
# Nur_Close_The_Window.gmm
# -23.953157853767557
# Nur_Open_The_Door.gmm
# -23.375648144491755
# Nur_Open_The_Window.gmm
# -23.24144155163108
# Omar_Close_The_Door.gmm
# -35.84661933743512
# Omar_Close_The_Window.gmm
# -27.808924570859617
# Omar_Open_The_Door.gmm
# -26.443525300274498
# Omar_Open_The_Window.gmm
# -28.56798094372948
# Salman_Close_The_Door.gmm
# -27.46932460810553
# Salman_Close_The_Window.gmm
# -27.000139804787082
# Salman_Open_The_Door.gmm
# -28.96758884134327
# Salman_Open_The_Window.gmm
# -29.712927954342913
# 	detected as -  Nur_Open_The_Window
# MaxScore = -23.24144155163108
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Nourhan\open_the_door_nourhan-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -30.543128973208486
# Neveen_Close_The_Window.gmm
# -31.904948823763323
# Neveen_Open_The_Door.gmm
# -29.603626727923714
# Neveen_Open_The_Window.gmm
# -31.859238037201578
# Nur_Close_The_Door.gmm
# -26.544117750584952
# Nur_Close_The_Window.gmm
# -24.838763966926006
# Nur_Open_The_Door.gmm
# -23.0923680966566
# Nur_Open_The_Window.gmm
# -24.35054762097533
# Omar_Close_The_Door.gmm
# -36.501708682719574
# Omar_Close_The_Window.gmm
# -29.99622763103987
# Omar_Open_The_Door.gmm
# -28.734823281183388
# Omar_Open_The_Window.gmm
# -30.002604440112073
# Salman_Close_The_Door.gmm
# -27.04231764767151
# Salman_Close_The_Window.gmm
# -26.865156411723287
# Salman_Open_The_Door.gmm
# -27.96705669927007
# Salman_Open_The_Window.gmm
# -29.92589738959528
# 	detected as -  Nur_Open_The_Door
# MaxScore = -23.0923680966566
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Nourhan\open_the_door_nourhan-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -26.50105471380924
# Neveen_Close_The_Window.gmm
# -28.15178556094664
# Neveen_Open_The_Door.gmm
# -25.269698980004872
# Neveen_Open_The_Window.gmm
# -27.498032033370354
# Nur_Close_The_Door.gmm
# -25.516469229521707
# Nur_Close_The_Window.gmm
# -25.910709678743892
# Nur_Open_The_Door.gmm
# -20.50661979708897
# Nur_Open_The_Window.gmm
# -24.085631538536717
# Omar_Close_The_Door.gmm
# -32.403898709893724
# Omar_Close_The_Window.gmm
# -28.454993322249173
# Omar_Open_The_Door.gmm
# -24.910478834213137
# Omar_Open_The_Window.gmm
# -26.938049899012427
# Salman_Close_The_Door.gmm
# -28.579211039120448
# Salman_Close_The_Window.gmm
# -25.854296962686945
# Salman_Open_The_Door.gmm
# -27.817234344013198
# Salman_Open_The_Window.gmm
# -28.890151233201337
# 	detected as -  Nur_Open_The_Door
# MaxScore = -20.50661979708897
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Nourhan\open_the_window_nourhan-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -27.04923743346814
# Neveen_Close_The_Window.gmm
# -27.403980270633593
# Neveen_Open_The_Door.gmm
# -26.571417356598683
# Neveen_Open_The_Window.gmm
# -27.421711633744263
# Nur_Close_The_Door.gmm
# -25.545499399097427
# Nur_Close_The_Window.gmm
# -20.95368363484163
# Nur_Open_The_Door.gmm
# -21.11620615700618
# Nur_Open_The_Window.gmm
# -19.01100279653986
# Omar_Close_The_Door.gmm
# -36.14179190218929
# Omar_Close_The_Window.gmm
# -30.768020162071913
# Omar_Open_The_Door.gmm
# -26.434395458281987
# Omar_Open_The_Window.gmm
# -29.538407639961033
# Salman_Close_The_Door.gmm
# -31.341450302382004
# Salman_Close_The_Window.gmm
# -27.92303965146206
# Salman_Open_The_Door.gmm
# -30.88979033522627
# Salman_Open_The_Window.gmm
# -30.980332995509706
# 	detected as -  Nur_Open_The_Window
# MaxScore = -19.01100279653986
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Nourhan\open_the_window_nourhan-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -25.69828053837068
# Neveen_Close_The_Window.gmm
# -26.76599914894174
# Neveen_Open_The_Door.gmm
# -25.804110652518293
# Neveen_Open_The_Window.gmm
# -26.64225485174757
# Nur_Close_The_Door.gmm
# -24.81667901145529
# Nur_Close_The_Window.gmm
# -20.618078342196938
# Nur_Open_The_Door.gmm
# -21.661275156616014
# Nur_Open_The_Window.gmm
# -18.519330887360304
# Omar_Close_The_Door.gmm
# -36.831080054723216
# Omar_Close_The_Window.gmm
# -30.77756534733164
# Omar_Open_The_Door.gmm
# -26.15539711436001
# Omar_Open_The_Window.gmm
# -28.960723846086086
# Salman_Close_The_Door.gmm
# -28.53413396001696
# Salman_Close_The_Window.gmm
# -27.773018196647804
# Salman_Open_The_Door.gmm
# -29.269652939977053
# Salman_Open_The_Window.gmm
# -29.36694400955606
# 	detected as -  Nur_Open_The_Window
# MaxScore = -18.519330887360304
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Omar\Close_The_Door_Omar-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -34.51511811830965
# Neveen_Close_The_Window.gmm
# -34.390838509475294
# Neveen_Open_The_Door.gmm
# -33.84802274535635
# Neveen_Open_The_Window.gmm
# -36.6753000680706
# Nur_Close_The_Door.gmm
# -32.7805141116445
# Nur_Close_The_Window.gmm
# -30.602465029429634
# Nur_Open_The_Door.gmm
# -33.50351745676341
# Nur_Open_The_Window.gmm
# -33.504732645857054
# Omar_Close_The_Door.gmm
# -33.461737424223834
# Omar_Close_The_Window.gmm
# -29.87382329147033
# Omar_Open_The_Door.gmm
# -31.328803169240672
# Omar_Open_The_Window.gmm
# -30.61948579502955
# Salman_Close_The_Door.gmm
# -31.638258520800438
# Salman_Close_The_Window.gmm
# -29.551783024789405
# Salman_Open_The_Door.gmm
# -31.10173358522693
# Salman_Open_The_Window.gmm
# -34.25107897502993
# 	detected as -  Salman_Close_The_Window
# MaxScore = -29.551783024789405
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Close_The_Door_Omar-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -34.01947096721079
# Neveen_Close_The_Window.gmm
# -34.18448592181595
# Neveen_Open_The_Door.gmm
# -34.07554316492181
# Neveen_Open_The_Window.gmm
# -36.881070877211215
# Nur_Close_The_Door.gmm
# -33.40288174942643
# Nur_Close_The_Window.gmm
# -30.81485722125863
# Nur_Open_The_Door.gmm
# -33.08249144992315
# Nur_Open_The_Window.gmm
# -34.05684766625788
# Omar_Close_The_Door.gmm
# -32.67777391339915
# Omar_Close_The_Window.gmm
# -30.048737441088694
# Omar_Open_The_Door.gmm
# -30.855278202806034
# Omar_Open_The_Window.gmm
# -30.181587701241913
# Salman_Close_The_Door.gmm
# -31.33481049543091
# Salman_Close_The_Window.gmm
# -29.298840881218418
# Salman_Open_The_Door.gmm
# -30.77393658619499
# Salman_Open_The_Window.gmm
# -33.6007586418222
# 	detected as -  Salman_Close_The_Window
# MaxScore = -29.298840881218418
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Close_The_Door_Omar.wav
#
# Neveen_Close_The_Door.gmm
# -35.7004795889275
# Neveen_Close_The_Window.gmm
# -35.942902953020194
# Neveen_Open_The_Door.gmm
# -34.75630296098726
# Neveen_Open_The_Window.gmm
# -39.0890243798157
# Nur_Close_The_Door.gmm
# -32.22451563358559
# Nur_Close_The_Window.gmm
# -30.160826428456573
# Nur_Open_The_Door.gmm
# -31.941276483820232
# Nur_Open_The_Window.gmm
# -34.21599577709793
# Omar_Close_The_Door.gmm
# -33.396169833202926
# Omar_Close_The_Window.gmm
# -30.735814633247983
# Omar_Open_The_Door.gmm
# -32.0509381633793
# Omar_Open_The_Window.gmm
# -31.460886932001657
# Salman_Close_The_Door.gmm
# -30.37325969824292
# Salman_Close_The_Window.gmm
# -30.295096062146435
# Salman_Open_The_Door.gmm
# -30.12755408835046
# Salman_Open_The_Window.gmm
# -33.51641343343044
# 	detected as -  Salman_Open_The_Door
# MaxScore = -30.12755408835046
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Close_The_Window_Omar-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -33.46225173657702
# Neveen_Close_The_Window.gmm
# -35.233781672206526
# Neveen_Open_The_Door.gmm
# -33.96154523753367
# Neveen_Open_The_Window.gmm
# -37.68351441721556
# Nur_Close_The_Door.gmm
# -35.24559513560795
# Nur_Close_The_Window.gmm
# -30.4856683937215
# Nur_Open_The_Door.gmm
# -35.049855379429644
# Nur_Open_The_Window.gmm
# -31.774213026575747
# Omar_Close_The_Door.gmm
# -34.443367451080924
# Omar_Close_The_Window.gmm
# -31.190970668473142
# Omar_Open_The_Door.gmm
# -32.20227199391811
# Omar_Open_The_Window.gmm
# -30.30965704593158
# Salman_Close_The_Door.gmm
# -31.613498957797113
# Salman_Close_The_Window.gmm
# -29.288019796245816
# Salman_Open_The_Door.gmm
# -30.068739223787336
# Salman_Open_The_Window.gmm
# -32.5497910671996
# 	detected as -  Salman_Close_The_Window
# MaxScore = -29.288019796245816
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Close_The_Window_Omar-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -32.55102044079592
# Neveen_Close_The_Window.gmm
# -33.71777691074014
# Neveen_Open_The_Door.gmm
# -32.90873982888288
# Neveen_Open_The_Window.gmm
# -36.618342998056356
# Nur_Close_The_Door.gmm
# -33.774012073073365
# Nur_Close_The_Window.gmm
# -29.069260706466405
# Nur_Open_The_Door.gmm
# -33.145705720089126
# Nur_Open_The_Window.gmm
# -30.403223240088444
# Omar_Close_The_Door.gmm
# -33.954220028879206
# Omar_Close_The_Window.gmm
# -30.057609711241618
# Omar_Open_The_Door.gmm
# -30.59318363479661
# Omar_Open_The_Window.gmm
# -29.61920008596441
# Salman_Close_The_Door.gmm
# -30.377488247518052
# Salman_Close_The_Window.gmm
# -28.905255542815734
# Salman_Open_The_Door.gmm
# -29.182279270737634
# Salman_Open_The_Window.gmm
# -31.303376658936845
# 	detected as -  Salman_Close_The_Window
# MaxScore = -28.905255542815734
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Close_The_Window_Omar.wav
#
# Neveen_Close_The_Door.gmm
# -33.12644620784545
# Neveen_Close_The_Window.gmm
# -33.99916959617212
# Neveen_Open_The_Door.gmm
# -33.77936980740245
# Neveen_Open_The_Window.gmm
# -37.460680432542034
# Nur_Close_The_Door.gmm
# -33.45119543461023
# Nur_Close_The_Window.gmm
# -29.610742396199964
# Nur_Open_The_Door.gmm
# -33.67680055233171
# Nur_Open_The_Window.gmm
# -31.9745625104018
# Omar_Close_The_Door.gmm
# -34.170489124669054
# Omar_Close_The_Window.gmm
# -30.696765984592343
# Omar_Open_The_Door.gmm
# -31.709112254927643
# Omar_Open_The_Window.gmm
# -29.768145791866026
# Salman_Close_The_Door.gmm
# -30.50857663429169
# Salman_Close_The_Window.gmm
# -28.394632015786577
# Salman_Open_The_Door.gmm
# -28.43480930729222
# Salman_Open_The_Window.gmm
# -30.365646134450028
# 	detected as -  Salman_Close_The_Window
# MaxScore = -28.394632015786577
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Good_Morning_Omar-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -35.21550931821412
# Neveen_Close_The_Window.gmm
# -34.05229977352783
# Neveen_Open_The_Door.gmm
# -32.685209313961735
# Neveen_Open_The_Window.gmm
# -37.09081582420117
# Nur_Close_The_Door.gmm
# -35.31646132792632
# Nur_Close_The_Window.gmm
# -28.94256285015761
# Nur_Open_The_Door.gmm
# -30.288539829743186
# Nur_Open_The_Window.gmm
# -30.30763600000481
# Omar_Close_The_Door.gmm
# -34.01833885465063
# Omar_Close_The_Window.gmm
# -31.13562136726481
# Omar_Open_The_Door.gmm
# -32.27916485653963
# Omar_Open_The_Window.gmm
# -30.00728400638883
# Salman_Close_The_Door.gmm
# -32.65876634976736
# Salman_Close_The_Window.gmm
# -29.980409367612406
# Salman_Open_The_Door.gmm
# -30.318585565267956
# Salman_Open_The_Window.gmm
# -31.904889337081467
# 	detected as -  Nur_Close_The_Window
# MaxScore = -28.94256285015761
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Good_Morning_Omar-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -35.8821217690393
# Neveen_Close_The_Window.gmm
# -35.428456942340034
# Neveen_Open_The_Door.gmm
# -33.36011101710734
# Neveen_Open_The_Window.gmm
# -37.447775663219616
# Nur_Close_The_Door.gmm
# -35.383906791119
# Nur_Close_The_Window.gmm
# -29.364550233739976
# Nur_Open_The_Door.gmm
# -31.549151085572994
# Nur_Open_The_Window.gmm
# -31.251413910982354
# Omar_Close_The_Door.gmm
# -34.22283954736374
# Omar_Close_The_Window.gmm
# -32.34858052456588
# Omar_Open_The_Door.gmm
# -32.22058137011642
# Omar_Open_The_Window.gmm
# -29.774154707125223
# Salman_Close_The_Door.gmm
# -32.642976408361235
# Salman_Close_The_Window.gmm
# -30.321690900121553
# Salman_Open_The_Door.gmm
# -29.95686685369348
# Salman_Open_The_Window.gmm
# -32.49475675217021
# 	detected as -  Nur_Close_The_Window
# MaxScore = -29.364550233739976
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Good_Morning_Omar.wav
#
# Neveen_Close_The_Door.gmm
# -35.70771747175167
# Neveen_Close_The_Window.gmm
# -34.27772378873984
# Neveen_Open_The_Door.gmm
# -34.143982786047665
# Neveen_Open_The_Window.gmm
# -37.75106131248734
# Nur_Close_The_Door.gmm
# -35.997260537963385
# Nur_Close_The_Window.gmm
# -31.560907010418223
# Nur_Open_The_Door.gmm
# -33.266897764263206
# Nur_Open_The_Window.gmm
# -32.43400588024739
# Omar_Close_The_Door.gmm
# -36.18921235480453
# Omar_Close_The_Window.gmm
# -34.016688639130216
# Omar_Open_The_Door.gmm
# -33.88432119200534
# Omar_Open_The_Window.gmm
# -32.3102106988708
# Salman_Close_The_Door.gmm
# -33.627676814020624
# Salman_Close_The_Window.gmm
# -31.76893112265629
# Salman_Open_The_Door.gmm
# -32.0702872755459
# Salman_Open_The_Window.gmm
# -32.940797294370434
# 	detected as -  Nur_Close_The_Window
# MaxScore = -31.560907010418223
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Open_The_Door_Omar-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -33.11120814109947
# Neveen_Close_The_Window.gmm
# -32.73206646288848
# Neveen_Open_The_Door.gmm
# -30.47554030204694
# Neveen_Open_The_Window.gmm
# -34.10822756462529
# Nur_Close_The_Door.gmm
# -32.379354442056325
# Nur_Close_The_Window.gmm
# -27.540493724340816
# Nur_Open_The_Door.gmm
# -28.530192406922442
# Nur_Open_The_Window.gmm
# -28.894624988177085
# Omar_Close_The_Door.gmm
# -31.587419679134506
# Omar_Close_The_Window.gmm
# -28.43177186162953
# Omar_Open_The_Door.gmm
# -29.394294619990223
# Omar_Open_The_Window.gmm
# -28.145307767016096
# Salman_Close_The_Door.gmm
# -29.886810808820535
# Salman_Close_The_Window.gmm
# -27.123477551501214
# Salman_Open_The_Door.gmm
# -28.268542686884217
# Salman_Open_The_Window.gmm
# -29.548207027521062
# 	detected as -  Salman_Close_The_Window
# MaxScore = -27.123477551501214
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Open_The_Door_Omar-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -34.741550033843744
# Neveen_Close_The_Window.gmm
# -33.69536028033228
# Neveen_Open_The_Door.gmm
# -32.951314536535726
# Neveen_Open_The_Window.gmm
# -36.989616774427375
# Nur_Close_The_Door.gmm
# -32.82748180398304
# Nur_Close_The_Window.gmm
# -28.77210445915117
# Nur_Open_The_Door.gmm
# -29.94034057148385
# Nur_Open_The_Window.gmm
# -31.32988058844
# Omar_Close_The_Door.gmm
# -33.53638849146497
# Omar_Close_The_Window.gmm
# -29.418825625332477
# Omar_Open_The_Door.gmm
# -30.30106700200947
# Omar_Open_The_Window.gmm
# -28.763921873978582
# Salman_Close_The_Door.gmm
# -30.66588526169578
# Salman_Close_The_Window.gmm
# -28.97298794805365
# Salman_Open_The_Door.gmm
# -29.027564908311994
# Salman_Open_The_Window.gmm
# -31.700585565639084
# 	detected as -  Omar_Open_The_Window
# MaxScore = -28.763921873978582
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Open_The_Door_Omar.wav
#
# Neveen_Close_The_Door.gmm
# -33.563324470600534
# Neveen_Close_The_Window.gmm
# -33.37841842752447
# Neveen_Open_The_Door.gmm
# -31.747414444289554
# Neveen_Open_The_Window.gmm
# -35.75174623924124
# Nur_Close_The_Door.gmm
# -31.491124699695984
# Nur_Close_The_Window.gmm
# -27.531004915304738
# Nur_Open_The_Door.gmm
# -30.11086894105311
# Nur_Open_The_Window.gmm
# -29.370491959579287
# Omar_Close_The_Door.gmm
# -31.974474553266855
# Omar_Close_The_Window.gmm
# -29.537621437082223
# Omar_Open_The_Door.gmm
# -29.29841926245689
# Omar_Open_The_Window.gmm
# -28.319203306851932
# Salman_Close_The_Door.gmm
# -29.708571539379385
# Salman_Close_The_Window.gmm
# -28.249006176440343
# Salman_Open_The_Door.gmm
# -28.176869418860374
# Salman_Open_The_Window.gmm
# -31.198203634806564
# 	detected as -  Nur_Close_The_Window
# MaxScore = -27.531004915304738
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Open_The_Window_Omar-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -35.45652782632906
# Neveen_Close_The_Window.gmm
# -36.450807442137254
# Neveen_Open_The_Door.gmm
# -34.43929842877457
# Neveen_Open_The_Window.gmm
# -39.68661811822591
# Nur_Close_The_Door.gmm
# -36.947401308984084
# Nur_Close_The_Window.gmm
# -31.17523722938168
# Nur_Open_The_Door.gmm
# -33.031076340867486
# Nur_Open_The_Window.gmm
# -31.107816317313482
# Omar_Close_The_Door.gmm
# -36.79611913704224
# Omar_Close_The_Window.gmm
# -32.23521661445507
# Omar_Open_The_Door.gmm
# -33.67394149924278
# Omar_Open_The_Window.gmm
# -30.720053658351564
# Salman_Close_The_Door.gmm
# -32.08572694373674
# Salman_Close_The_Window.gmm
# -29.207670827271507
# Salman_Open_The_Door.gmm
# -30.586748772447788
# Salman_Open_The_Window.gmm
# -33.117903789152834
# 	detected as -  Salman_Close_The_Window
# MaxScore = -29.207670827271507
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Open_The_Window_Omar-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -31.9819168767932
# Neveen_Close_The_Window.gmm
# -32.35575011058588
# Neveen_Open_The_Door.gmm
# -30.29302987843143
# Neveen_Open_The_Window.gmm
# -34.2797708506819
# Nur_Close_The_Door.gmm
# -30.889365227797118
# Nur_Close_The_Window.gmm
# -26.33344846415231
# Nur_Open_The_Door.gmm
# -27.063981989351085
# Nur_Open_The_Window.gmm
# -28.056715089412634
# Omar_Close_The_Door.gmm
# -32.71110861313494
# Omar_Close_The_Window.gmm
# -27.426070973789333
# Omar_Open_The_Door.gmm
# -28.336468760573332
# Omar_Open_The_Window.gmm
# -26.65746823565049
# Salman_Close_The_Door.gmm
# -27.95090282632283
# Salman_Close_The_Window.gmm
# -26.860331104008882
# Salman_Open_The_Door.gmm
# -25.791281995930838
# Salman_Open_The_Window.gmm
# -27.927012311936448
# 	detected as -  Salman_Open_The_Door
# MaxScore = -25.791281995930838
# --------------------------------------------------
# Other
# ##################################################
# Test File : Omar\Open_The_Window_Omar.wav
#
# Neveen_Close_The_Door.gmm
# -34.573934271627046
# Neveen_Close_The_Window.gmm
# -34.63181181962622
# Neveen_Open_The_Door.gmm
# -33.396091996084074
# Neveen_Open_The_Window.gmm
# -38.220071999676414
# Nur_Close_The_Door.gmm
# -34.43943029302849
# Nur_Close_The_Window.gmm
# -29.47047102507533
# Nur_Open_The_Door.gmm
# -31.972837565876272
# Nur_Open_The_Window.gmm
# -30.81789164104218
# Omar_Close_The_Door.gmm
# -34.83018039847553
# Omar_Close_The_Window.gmm
# -31.78775034359783
# Omar_Open_The_Door.gmm
# -31.57288286954191
# Omar_Open_The_Window.gmm
# -29.699998557351318
# Salman_Close_The_Door.gmm
# -31.763035952268083
# Salman_Close_The_Window.gmm
# -28.945667663637128
# Salman_Open_The_Door.gmm
# -29.474408969558265
# Salman_Open_The_Window.gmm
# -30.25743356416092
# 	detected as -  Salman_Close_The_Window
# MaxScore = -28.945667663637128
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\doha.wav
#
# Neveen_Close_The_Door.gmm
# -34.609717955487085
# Neveen_Close_The_Window.gmm
# -33.9618262350477
# Neveen_Open_The_Door.gmm
# -34.26639940135266
# Neveen_Open_The_Window.gmm
# -37.010760652813914
# Nur_Close_The_Door.gmm
# -36.27166898836087
# Nur_Close_The_Window.gmm
# -32.47511731073596
# Nur_Open_The_Door.gmm
# -35.02085634048962
# Nur_Open_The_Window.gmm
# -34.432237333826464
# Omar_Close_The_Door.gmm
# -40.42900247230001
# Omar_Close_The_Window.gmm
# -34.983584237843516
# Omar_Open_The_Door.gmm
# -35.461387480758596
# Omar_Open_The_Window.gmm
# -34.675653211382915
# Salman_Close_The_Door.gmm
# -34.32104086777212
# Salman_Close_The_Window.gmm
# -33.127945537869635
# Salman_Open_The_Door.gmm
# -33.452181135174335
# Salman_Open_The_Window.gmm
# -34.90955208120284
# 	detected as -  Nur_Close_The_Window
# MaxScore = -32.47511731073596
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\dr1.wav
#
# Neveen_Close_The_Door.gmm
# -35.79048554482987
# Neveen_Close_The_Window.gmm
# -35.84727190159549
# Neveen_Open_The_Door.gmm
# -36.609714562699565
# Neveen_Open_The_Window.gmm
# -37.88115480643571
# Nur_Close_The_Door.gmm
# -39.215823920972305
# Nur_Close_The_Window.gmm
# -33.80518249748157
# Nur_Open_The_Door.gmm
# -36.00473113881546
# Nur_Open_The_Window.gmm
# -36.81067567548986
# Omar_Close_The_Door.gmm
# -40.049241361465555
# Omar_Close_The_Window.gmm
# -36.743241292219274
# Omar_Open_The_Door.gmm
# -37.163048447825865
# Omar_Open_The_Window.gmm
# -35.74028218353424
# Salman_Close_The_Door.gmm
# -36.881238901415905
# Salman_Close_The_Window.gmm
# -35.19938344335014
# Salman_Open_The_Door.gmm
# -35.82709388384016
# Salman_Open_The_Window.gmm
# -38.088184252872466
# 	detected as -  Nur_Close_The_Window
# MaxScore = -33.80518249748157
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\dr2.wav
#
# Neveen_Close_The_Door.gmm
# -36.91782862749586
# Neveen_Close_The_Window.gmm
# -35.941391864114465
# Neveen_Open_The_Door.gmm
# -37.33521757760766
# Neveen_Open_The_Window.gmm
# -38.05425519779217
# Nur_Close_The_Door.gmm
# -38.667815923455905
# Nur_Close_The_Window.gmm
# -33.80815379749328
# Nur_Open_The_Door.gmm
# -36.312281468653026
# Nur_Open_The_Window.gmm
# -36.00350912834806
# Omar_Close_The_Door.gmm
# -41.264366567873004
# Omar_Close_The_Window.gmm
# -37.14454106693595
# Omar_Open_The_Door.gmm
# -38.13637723169851
# Omar_Open_The_Window.gmm
# -36.6005997759416
# Salman_Close_The_Door.gmm
# -37.04188231770974
# Salman_Close_The_Window.gmm
# -35.574581600784114
# Salman_Open_The_Door.gmm
# -36.331718393406256
# Salman_Open_The_Window.gmm
# -39.35510112042688
# 	detected as -  Nur_Close_The_Window
# MaxScore = -33.80815379749328
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\Ehab-sample10.wav
#
# Neveen_Close_The_Door.gmm
# -32.97662781392965
# Neveen_Close_The_Window.gmm
# -33.64474343099807
# Neveen_Open_The_Door.gmm
# -33.15475125527217
# Neveen_Open_The_Window.gmm
# -36.187210425036554
# Nur_Close_The_Door.gmm
# -35.75094850711475
# Nur_Close_The_Window.gmm
# -31.125345779769518
# Nur_Open_The_Door.gmm
# -32.92104480580133
# Nur_Open_The_Window.gmm
# -31.090036623387427
# Omar_Close_The_Door.gmm
# -37.65902990434843
# Omar_Close_The_Window.gmm
# -34.94148534841608
# Omar_Open_The_Door.gmm
# -34.83440099740202
# Omar_Open_The_Window.gmm
# -32.09641628615179
# Salman_Close_The_Door.gmm
# -31.700219887835978
# Salman_Close_The_Window.gmm
# -31.468521755785634
# Salman_Open_The_Door.gmm
# -29.900295530164932
# Salman_Open_The_Window.gmm
# -34.47093661847561
# 	detected as -  Salman_Open_The_Door
# MaxScore = -29.900295530164932
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\empty.wav
#
# Neveen_Close_The_Door.gmm
# -36.64333327291136
# Neveen_Close_The_Window.gmm
# -37.106471094036436
# Neveen_Open_The_Door.gmm
# -36.40552906179642
# Neveen_Open_The_Window.gmm
# -39.317896642296745
# Nur_Close_The_Door.gmm
# -36.558679586432206
# Nur_Close_The_Window.gmm
# -36.2404808238677
# Nur_Open_The_Door.gmm
# -34.02022686292857
# Nur_Open_The_Window.gmm
# -37.93435257413544
# Omar_Close_The_Door.gmm
# -44.24232081154881
# Omar_Close_The_Window.gmm
# -36.0373239903632
# Omar_Open_The_Door.gmm
# -35.62451398379254
# Omar_Open_The_Window.gmm
# -34.68342866442038
# Salman_Close_The_Door.gmm
# -35.013188553673004
# Salman_Close_The_Window.gmm
# -33.5541396384766
# Salman_Open_The_Door.gmm
# -35.44597251869533
# Salman_Open_The_Window.gmm
# -37.69829748216753
# 	detected as -  Salman_Close_The_Window
# MaxScore = -33.5541396384766
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\neven.wav
#
# Neveen_Close_The_Door.gmm
# -35.516186298418624
# Neveen_Close_The_Window.gmm
# -36.88575313002572
# Neveen_Open_The_Door.gmm
# -35.310410002356605
# Neveen_Open_The_Window.gmm
# -37.93897822231444
# Nur_Close_The_Door.gmm
# -39.78801869269881
# Nur_Close_The_Window.gmm
# -35.203448312944616
# Nur_Open_The_Door.gmm
# -36.74353037708837
# Nur_Open_The_Window.gmm
# -35.18975755793347
# Omar_Close_The_Door.gmm
# -40.85440728893527
# Omar_Close_The_Window.gmm
# -37.099594906299295
# Omar_Open_The_Door.gmm
# -38.568766941981856
# Omar_Open_The_Window.gmm
# -35.57087403082282
# Salman_Close_The_Door.gmm
# -37.039734613334176
# Salman_Close_The_Window.gmm
# -35.65035398306451
# Salman_Open_The_Door.gmm
# -35.916559759782075
# Salman_Open_The_Window.gmm
# -41.653395127927936
# 	detected as -  Nur_Open_The_Window
# MaxScore = -35.18975755793347
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\nevveeen.wav
#
# Neveen_Close_The_Door.gmm
# -35.15601345457802
# Neveen_Close_The_Window.gmm
# -36.227404982875925
# Neveen_Open_The_Door.gmm
# -34.22915648482163
# Neveen_Open_The_Window.gmm
# -35.98892798661488
# Nur_Close_The_Door.gmm
# -38.51829541038274
# Nur_Close_The_Window.gmm
# -34.5617138066147
# Nur_Open_The_Door.gmm
# -36.848404528794426
# Nur_Open_The_Window.gmm
# -36.957268956480874
# Omar_Close_The_Door.gmm
# -42.609626425267614
# Omar_Close_The_Window.gmm
# -37.1746839896517
# Omar_Open_The_Door.gmm
# -37.07457928057293
# Omar_Open_The_Window.gmm
# -36.02963276818778
# Salman_Close_The_Door.gmm
# -37.286212111070824
# Salman_Close_The_Window.gmm
# -35.065133751084936
# Salman_Open_The_Door.gmm
# -35.962315749745095
# Salman_Open_The_Window.gmm
# -40.422754136563555
# 	detected as -  Neveen_Open_The_Door
# MaxScore = -34.22915648482163
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\nurhaan.wav
#
# Neveen_Close_The_Door.gmm
# -24.48228087360155
# Neveen_Close_The_Window.gmm
# -28.199491532070954
# Neveen_Open_The_Door.gmm
# -23.629363121268717
# Neveen_Open_The_Window.gmm
# -25.673572022884546
# Nur_Close_The_Door.gmm
# -31.981401572310183
# Nur_Close_The_Window.gmm
# -31.040558636151907
# Nur_Open_The_Door.gmm
# -25.172381437742352
# Nur_Open_The_Window.gmm
# -26.01204303620325
# Omar_Close_The_Door.gmm
# -24.56263137942734
# Omar_Close_The_Window.gmm
# -26.92980852383803
# Omar_Open_The_Door.gmm
# -24.38399386100402
# Omar_Open_The_Window.gmm
# -24.341492385190467
# Salman_Close_The_Door.gmm
# -27.825402696702277
# Salman_Close_The_Window.gmm
# -25.539799065430948
# Salman_Open_The_Door.gmm
# -26.432446139217603
# Salman_Open_The_Window.gmm
# -29.580755871491274
# 	detected as -  Neveen_Open_The_Door
# MaxScore = -23.629363121268717
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : others\nurhan.wav
#
# Neveen_Close_The_Door.gmm
# -37.6880342958887
# Neveen_Close_The_Window.gmm
# -37.75158099053464
# Neveen_Open_The_Door.gmm
# -37.74128731862684
# Neveen_Open_The_Window.gmm
# -38.3252686197761
# Nur_Close_The_Door.gmm
# -41.66878651780452
# Nur_Close_The_Window.gmm
# -34.12047134643443
# Nur_Open_The_Door.gmm
# -39.361094695259126
# Nur_Open_The_Window.gmm
# -38.93536180974386
# Omar_Close_The_Door.gmm
# -41.878964488767856
# Omar_Close_The_Window.gmm
# -35.82261599434067
# Omar_Open_The_Door.gmm
# -37.80032206987135
# Omar_Open_The_Window.gmm
# -36.801412342015475
# Salman_Close_The_Door.gmm
# -36.250416871757864
# Salman_Close_The_Window.gmm
# -34.80945226806948
# Salman_Open_The_Door.gmm
# -36.14380861617155
# Salman_Open_The_Window.gmm
# -40.34609845781178
# 	detected as -  Nur_Close_The_Window
# MaxScore = -34.12047134643443
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\omar.wav
#
# Neveen_Close_The_Door.gmm
# -31.02557942289494
# Neveen_Close_The_Window.gmm
# -31.77838502695768
# Neveen_Open_The_Door.gmm
# -30.044525392255064
# Neveen_Open_The_Window.gmm
# -31.707110157043918
# Nur_Close_The_Door.gmm
# -32.96840227594495
# Nur_Close_The_Window.gmm
# -32.388975859219094
# Nur_Open_The_Door.gmm
# -28.987015675354467
# Nur_Open_The_Window.gmm
# -31.26648520240714
# Omar_Close_The_Door.gmm
# -31.980419751784677
# Omar_Close_The_Window.gmm
# -29.416023084319928
# Omar_Open_The_Door.gmm
# -25.987552779487338
# Omar_Open_The_Window.gmm
# -26.257612062769205
# Salman_Close_The_Door.gmm
# -28.363625781039126
# Salman_Close_The_Window.gmm
# -28.527515286932147
# Salman_Open_The_Door.gmm
# -26.331101804893642
# Salman_Open_The_Window.gmm
# -30.989991966689796
# 	detected as -  Omar_Open_The_Door
# MaxScore = -25.987552779487338
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\omarTest (1).wav
#
# Neveen_Close_The_Door.gmm
# -33.65788548031677
# Neveen_Close_The_Window.gmm
# -33.47166907135726
# Neveen_Open_The_Door.gmm
# -32.21193168334748
# Neveen_Open_The_Window.gmm
# -36.41058397879472
# Nur_Close_The_Door.gmm
# -31.90638829670997
# Nur_Close_The_Window.gmm
# -28.21061619281161
# Nur_Open_The_Door.gmm
# -28.299399441360773
# Nur_Open_The_Window.gmm
# -27.78963882975259
# Omar_Close_The_Door.gmm
# -34.30039941472414
# Omar_Close_The_Window.gmm
# -31.368299512427832
# Omar_Open_The_Door.gmm
# -30.405415925895024
# Omar_Open_The_Window.gmm
# -30.36658833312201
# Salman_Close_The_Door.gmm
# -30.914588362924185
# Salman_Close_The_Window.gmm
# -29.107503325612647
# Salman_Open_The_Door.gmm
# -29.281335807247636
# Salman_Open_The_Window.gmm
# -32.16522536980566
# 	detected as -  Nur_Open_The_Window
# MaxScore = -27.78963882975259
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\omarTest (2).wav
#
# Neveen_Close_The_Door.gmm
# -29.518907825706613
# Neveen_Close_The_Window.gmm
# ...
# Test File : others\omar_open_door.wav
#
# Neveen_Close_The_Door.gmm
# -33.279372410185616
# Neveen_Close_The_Window.gmm
# -34.49356402015901
# Neveen_Open_The_Door.gmm
# -33.06710687910454
# Neveen_Open_The_Window.gmm
# -34.87576580041322
# Nur_Close_The_Door.gmm
# -33.834887824782825
# Nur_Close_The_Window.gmm
# -29.19806664510105
# Nur_Open_The_Door.gmm
# -30.077499674396375
# Nur_Open_The_Window.gmm
# -30.335771209159226
# Omar_Close_The_Door.gmm
# -36.357420688237774
# Omar_Close_The_Window.gmm
# -30.33419338910038
# Omar_Open_The_Door.gmm
# -28.41046145761146
# Omar_Open_The_Window.gmm
# -29.850742574457605
# Salman_Close_The_Door.gmm
# -29.974700738128742
# Salman_Close_The_Window.gmm
# -29.215681097256002
# Salman_Open_The_Door.gmm
# -29.85032150038978
# Salman_Open_The_Window.gmm
# -33.101843500707574
# 	detected as -  Omar_Open_The_Door
# MaxScore = -28.41046145761146
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\omar_open_window.wav
#
# Neveen_Close_The_Door.gmm
# -32.36226264536106
# Neveen_Close_The_Window.gmm
# -32.94474130646118
# Neveen_Open_The_Door.gmm
# -32.844028775442716
# Neveen_Open_The_Window.gmm
# -34.64377050704955
# Nur_Close_The_Door.gmm
# -32.929966948877755
# Nur_Close_The_Window.gmm
# -29.325799685249546
# Nur_Open_The_Door.gmm
# -30.052357084466177
# Nur_Open_The_Window.gmm
# -30.982293480419028
# Omar_Close_The_Door.gmm
# -37.3030174693747
# Omar_Close_The_Window.gmm
# -30.11328003620197
# Omar_Open_The_Door.gmm
# -29.847258631362276
# Omar_Open_The_Window.gmm
# -29.522109496929016
# Salman_Close_The_Door.gmm
# -31.73887394390544
# Salman_Close_The_Window.gmm
# -29.131928153435364
# Salman_Open_The_Door.gmm
# -31.20670538039155
# Salman_Open_The_Window.gmm
# -33.438969931544854
# 	detected as -  Salman_Close_The_Window
# MaxScore = -29.131928153435364
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\otthher.wav
#
# Neveen_Close_The_Door.gmm
# -30.413584796810188
# Neveen_Close_The_Window.gmm
# -32.141412272883024
# Neveen_Open_The_Door.gmm
# -28.84905481388544
# Neveen_Open_The_Window.gmm
# -31.476293017158657
# Nur_Close_The_Door.gmm
# -35.87999264126669
# Nur_Close_The_Window.gmm
# -34.71633368906633
# Nur_Open_The_Door.gmm
# -29.90088878410822
# Nur_Open_The_Window.gmm
# -31.929047178937346
# Omar_Close_The_Door.gmm
# -29.264394957798313
# Omar_Close_The_Window.gmm
# -30.88145989580091
# Omar_Open_The_Door.gmm
# -27.83516054419262
# Omar_Open_The_Window.gmm
# -28.50264111303868
# Salman_Close_The_Door.gmm
# -32.31519326057835
# Salman_Close_The_Window.gmm
# -30.005608423519632
# Salman_Open_The_Door.gmm
# -30.107846788128835
# Salman_Open_The_Window.gmm
# -34.474815005776435
# 	detected as -  Omar_Open_The_Door
# MaxScore = -27.83516054419262
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\Salman.wav
#
# Neveen_Close_The_Door.gmm
# -29.55423011885632
# Neveen_Close_The_Window.gmm
# -32.326563512450456
# Neveen_Open_The_Door.gmm
# -28.415977897527313
# Neveen_Open_The_Window.gmm
# -30.195498418439247
# Nur_Close_The_Door.gmm
# -34.71558301886761
# Nur_Close_The_Window.gmm
# -34.15692463359425
# Nur_Open_The_Door.gmm
# -30.272623649470468
# Nur_Open_The_Window.gmm
# -31.765304879870087
# Omar_Close_The_Door.gmm
# -26.6300033148084
# Omar_Close_The_Window.gmm
# -27.478811834896145
# Omar_Open_The_Door.gmm
# -26.120661339897215
# Omar_Open_The_Window.gmm
# -25.662047194263046
# Salman_Close_The_Door.gmm
# -26.414562020214884
# Salman_Close_The_Window.gmm
# -27.456129973327347
# Salman_Open_The_Door.gmm
# -24.95579018650457
# Salman_Open_The_Window.gmm
# -27.335426141958045
# 	detected as -  Salman_Open_The_Door
# MaxScore = -24.95579018650457
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\sample.wav
#
# Neveen_Close_The_Door.gmm
# -30.782101436271372
# Neveen_Close_The_Window.gmm
# -31.71212796064718
# Neveen_Open_The_Door.gmm
# -30.6049328443539
# Neveen_Open_The_Window.gmm
# -32.27932589405363
# Nur_Close_The_Door.gmm
# -27.034631889016122
# Nur_Close_The_Window.gmm
# -26.612527046603443
# Nur_Open_The_Door.gmm
# -27.225664725319884
# Nur_Open_The_Window.gmm
# -29.542967304171537
# Omar_Close_The_Door.gmm
# -35.80929485621956
# Omar_Close_The_Window.gmm
# -29.089387615612747
# Omar_Open_The_Door.gmm
# -27.70055880034119
# Omar_Open_The_Window.gmm
# -28.585556749966074
# Salman_Close_The_Door.gmm
# -26.86550559252231
# Salman_Close_The_Window.gmm
# -25.232792939193384
# Salman_Open_The_Door.gmm
# -27.63376925377153
# Salman_Open_The_Window.gmm
# -30.243136315830164
# 	detected as -  Salman_Close_The_Window
# MaxScore = -25.232792939193384
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\sarta.wav
#
# Neveen_Close_The_Door.gmm
# -30.6979736544034
# Neveen_Close_The_Window.gmm
# -34.06785649356691
# Neveen_Open_The_Door.gmm
# -30.27908835938631
# Neveen_Open_The_Window.gmm
# -31.96239147190755
# Nur_Close_The_Door.gmm
# -35.35489917731683
# Nur_Close_The_Window.gmm
# -34.44522490829409
# Nur_Open_The_Door.gmm
# -28.986898459454366
# Nur_Open_The_Window.gmm
# -31.943253836835854
# Omar_Close_The_Door.gmm
# -28.57080844152328
# Omar_Close_The_Window.gmm
# -28.865289388561827
# Omar_Open_The_Door.gmm
# -27.28982604616754
# Omar_Open_The_Window.gmm
# -27.877457394453824
# Salman_Close_The_Door.gmm
# -32.574446967242785
# Salman_Close_The_Window.gmm
# -30.07895835317439
# Salman_Open_The_Door.gmm
# -31.023875022744043
# Salman_Open_The_Window.gmm
# -34.86806262692082
# 	detected as -  Omar_Open_The_Door
# MaxScore = -27.28982604616754
# --------------------------------------------------
# Other
# ##################################################
# Test File : others\Sherif-sample9.wav
#
# Neveen_Close_The_Door.gmm
# -36.39304111186158
# Neveen_Close_The_Window.gmm
# -35.842791670023864
# Neveen_Open_The_Door.gmm
# -34.5232690392618
# Neveen_Open_The_Window.gmm
# -37.13547034247884
# Nur_Close_The_Door.gmm
# -34.36847320564672
# Nur_Close_The_Window.gmm
# -30.913931288828532
# Nur_Open_The_Door.gmm
# -35.35134782658054
# Nur_Open_The_Window.gmm
# -37.26280584241709
# Omar_Close_The_Door.gmm
# -38.294800693817145
# Omar_Close_The_Window.gmm
# -33.02871338317311
# Omar_Open_The_Door.gmm
# -34.8645604348202
# Omar_Open_The_Window.gmm
# -33.96828115077295
# Salman_Close_The_Door.gmm
# -34.99435073912086
# Salman_Close_The_Window.gmm
# -31.630676563724926
# Salman_Open_The_Door.gmm
# -32.17760833183862
# Salman_Open_The_Window.gmm
# -35.484256446992696
# 	detected as -  Nur_Close_The_Window
# MaxScore = -30.913931288828532
# --------------------------------------------------
# Other
# ##################################################
# Test File : Salman\close-the-door-salman-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -28.12273528547376
# Neveen_Close_The_Window.gmm
# -29.881360638171813
# Neveen_Open_The_Door.gmm
# -28.711744894613677
# Neveen_Open_The_Window.gmm
# -30.192610628644758
# Nur_Close_The_Door.gmm
# -29.25958849629263
# Nur_Close_The_Window.gmm
# -29.211098225887756
# Nur_Open_The_Door.gmm
# -28.167689173794237
# Nur_Open_The_Window.gmm
# -30.010792767466217
# Omar_Close_The_Door.gmm
# -31.41614344023599
# Omar_Close_The_Window.gmm
# -26.20743689124845
# Omar_Open_The_Door.gmm
# -25.821187335789308
# Omar_Open_The_Window.gmm
# -25.89628745133902
# Salman_Close_The_Door.gmm
# -19.80926796860365
# Salman_Close_The_Window.gmm
# -23.29781237948239
# Salman_Open_The_Door.gmm
# -22.90552544379569
# Salman_Open_The_Window.gmm
# -26.53881849845048
# 	detected as -  Salman_Close_The_Door
# MaxScore = -19.80926796860365
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\close-the-door-salman-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -27.80601854743333
# Neveen_Close_The_Window.gmm
# -29.881038003653895
# Neveen_Open_The_Door.gmm
# -28.026744156748208
# Neveen_Open_The_Window.gmm
# -30.005224000904096
# Nur_Close_The_Door.gmm
# -29.20727316471654
# Nur_Close_The_Window.gmm
# -30.728714516610985
# Nur_Open_The_Door.gmm
# -27.73033764050844
# Nur_Open_The_Window.gmm
# -29.22175066739106
# Omar_Close_The_Door.gmm
# -26.59259108502733
# Omar_Close_The_Window.gmm
# -25.72647673471795
# Omar_Open_The_Door.gmm
# -25.458061140304714
# Omar_Open_The_Window.gmm
# -25.78017656799262
# Salman_Close_The_Door.gmm
# -20.06600188441092
# Salman_Close_The_Window.gmm
# -23.340402111393526
# Salman_Open_The_Door.gmm
# -22.63663484763111
# Salman_Open_The_Window.gmm
# -26.436765012141162
# 	detected as -  Salman_Close_The_Door
# MaxScore = -20.06600188441092
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\close-the-window-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -30.97310396800361
# Neveen_Close_The_Window.gmm
# -31.48858147228695
# Neveen_Open_The_Door.gmm
# -31.96480505199976
# Neveen_Open_The_Window.gmm
# -32.437695386739094
# Nur_Close_The_Door.gmm
# -29.08387502316404
# Nur_Close_The_Window.gmm
# -30.230494923582974
# Nur_Open_The_Door.gmm
# -30.57677697686197
# Nur_Open_The_Window.gmm
# -32.111059285733525
# Omar_Close_The_Door.gmm
# -36.40770616761415
# Omar_Close_The_Window.gmm
# -28.531862120699866
# Omar_Open_The_Door.gmm
# -28.454485329306472
# Omar_Open_The_Window.gmm
# -27.274896699879267
# Salman_Close_The_Door.gmm
# -23.760205512674638
# Salman_Close_The_Window.gmm
# -24.2903255353146
# Salman_Open_The_Door.gmm
# -24.751713480597267
# Salman_Open_The_Window.gmm
# -25.831266007171536
# 	detected as -  Salman_Close_The_Door
# MaxScore = -23.760205512674638
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\close-the-window-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -27.479016727056134
# Neveen_Close_The_Window.gmm
# -29.87678738677761
# Neveen_Open_The_Door.gmm
# -26.782002633633912
# Neveen_Open_The_Window.gmm
# -28.402599126440307
# Nur_Close_The_Door.gmm
# -30.250609594007088
# Nur_Close_The_Window.gmm
# -31.77251720548975
# Nur_Open_The_Door.gmm
# -28.104839955913366
# Nur_Open_The_Window.gmm
# -29.238838750507647
# Omar_Close_The_Door.gmm
# -26.813428613002532
# Omar_Close_The_Window.gmm
# -28.18575725184465
# Omar_Open_The_Door.gmm
# -25.102910971862595
# Omar_Open_The_Window.gmm
# -24.893109911819824
# Salman_Close_The_Door.gmm
# -25.08646102012452
# Salman_Close_The_Window.gmm
# -23.174777652527474
# Salman_Open_The_Door.gmm
# -23.545005236430356
# Salman_Open_The_Window.gmm
# -26.010864710979703
# 	detected as -  Salman_Close_The_Window
# MaxScore = -23.174777652527474
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\goodmorning-salman-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -30.116871255110755
# Neveen_Close_The_Window.gmm
# -29.702779266347548
# Neveen_Open_The_Door.gmm
# -28.512623265268576
# Neveen_Open_The_Window.gmm
# -29.826760961524073
# Nur_Close_The_Door.gmm
# -28.08143361320837
# Nur_Close_The_Window.gmm
# -29.05395631324727
# Nur_Open_The_Door.gmm
# -26.23255770500535
# Nur_Open_The_Window.gmm
# -30.61502304438906
# Omar_Close_The_Door.gmm
# -34.10974261958071
# Omar_Close_The_Window.gmm
# -26.187864088480655
# Omar_Open_The_Door.gmm
# -24.5398585314856
# Omar_Open_The_Window.gmm
# -24.044049282482934
# Salman_Close_The_Door.gmm
# -27.19404874143497
# Salman_Close_The_Window.gmm
# -24.810273489762476
# Salman_Open_The_Door.gmm
# -24.858767092630043
# Salman_Open_The_Window.gmm
# -26.482618951912503
# 	detected as -  Omar_Open_The_Window
# MaxScore = -24.044049282482934
# --------------------------------------------------
# Other
# ##################################################
# Test File : Salman\goodmorning-salman-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -30.082393578226018
# Neveen_Close_The_Window.gmm
# -30.18573909707168
# Neveen_Open_The_Door.gmm
# -27.679623286074992
# Neveen_Open_The_Window.gmm
# -29.535199707773224
# Nur_Close_The_Door.gmm
# -27.940568020557823
# Nur_Close_The_Window.gmm
# -30.06636483904953
# Nur_Open_The_Door.gmm
# -25.946570513021932
# Nur_Open_The_Window.gmm
# -30.540980952001394
# Omar_Close_The_Door.gmm
# -35.06559884278983
# Omar_Close_The_Window.gmm
# -26.4105989046149
# Omar_Open_The_Door.gmm
# -25.12503379292276
# Omar_Open_The_Window.gmm
# -25.759042433877674
# Salman_Close_The_Door.gmm
# -27.409231996518297
# Salman_Close_The_Window.gmm
# -25.21422487859039
# Salman_Open_The_Door.gmm
# -25.986527685741052
# Salman_Open_The_Window.gmm
# -27.495739684209358
# 	detected as -  Omar_Open_The_Door
# MaxScore = -25.12503379292276
# --------------------------------------------------
# Other
# ##################################################
# Test File : Salman\open-the-window-salman-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -31.319000639010294
# Neveen_Close_The_Window.gmm
# -31.276145834596075
# Neveen_Open_The_Door.gmm
# -30.94516971635867
# Neveen_Open_The_Window.gmm
# -31.512457231943813
# Nur_Close_The_Door.gmm
# -28.575376549304277
# Nur_Close_The_Window.gmm
# -29.171397462698767
# Nur_Open_The_Door.gmm
# -28.647009875697684
# Nur_Open_The_Window.gmm
# -30.700981864680667
# Omar_Close_The_Door.gmm
# -36.38153700792759
# Omar_Close_The_Window.gmm
# -28.646025421797702
# Omar_Open_The_Door.gmm
# -27.482878063528467
# Omar_Open_The_Window.gmm
# -26.73526563712937
# Salman_Close_The_Door.gmm
# -23.845027970742
# Salman_Close_The_Window.gmm
# -23.450323934541114
# Salman_Open_The_Door.gmm
# -21.978310552200913
# Salman_Open_The_Window.gmm
# -21.30435141171681
# 	detected as -  Salman_Open_The_Window
# MaxScore = -21.30435141171681
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\open-the-window-salman-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -29.689729414461
# Neveen_Close_The_Window.gmm
# -29.34287124962592
# Neveen_Open_The_Door.gmm
# -29.220498901251247
# Neveen_Open_The_Window.gmm
# -30.128336341442868
# Nur_Close_The_Door.gmm
# -27.22128027802189
# Nur_Close_The_Window.gmm
# -28.306816973113982
# Nur_Open_The_Door.gmm
# -27.61931830712389
# Nur_Open_The_Window.gmm
# -29.779742010293248
# Omar_Close_The_Door.gmm
# -35.57132213192642
# Omar_Close_The_Window.gmm
# -27.411552982123983
# Omar_Open_The_Door.gmm
# -26.335890316890445
# Omar_Open_The_Window.gmm
# -25.93632458522827
# Salman_Close_The_Door.gmm
# -22.658715162597055
# Salman_Close_The_Window.gmm
# -24.19443689637271
# Salman_Open_The_Door.gmm
# -21.64796672412655
# Salman_Open_The_Window.gmm
# -20.53396807821615
# 	detected as -  Salman_Open_The_Window
# MaxScore = -20.53396807821615
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\open_the_door_salman-sample18.wav
#
# Neveen_Close_The_Door.gmm
# -25.983203396004207
# Neveen_Close_The_Window.gmm
# -27.97715683502821
# Neveen_Open_The_Door.gmm
# -24.491153671545327
# Neveen_Open_The_Window.gmm
# -26.877265918615688
# Nur_Close_The_Door.gmm
# -26.489505404711696
# Nur_Close_The_Window.gmm
# -27.20141575341123
# Nur_Open_The_Door.gmm
# -23.78724121630954
# Nur_Open_The_Window.gmm
# -23.783118472605803
# Omar_Close_The_Door.gmm
# -27.550964163214175
# Omar_Close_The_Window.gmm
# -25.440170351845165
# Omar_Open_The_Door.gmm
# -22.773710238282312
# Omar_Open_The_Window.gmm
# -23.548247319454884
# Salman_Close_The_Door.gmm
# -21.45963936187717
# Salman_Close_The_Window.gmm
# -22.02997737231081
# Salman_Open_The_Door.gmm
# -18.501688975792685
# Salman_Open_The_Window.gmm
# -20.61549233315948
# 	detected as -  Salman_Open_The_Door
# MaxScore = -18.501688975792685
# --------------------------------------------------
# Accepted
# ##################################################
# Test File : Salman\open_the_door_salman-sample19.wav
#
# Neveen_Close_The_Door.gmm
# -24.807830559026016
# Neveen_Close_The_Window.gmm
# -28.00647033680063
# Neveen_Open_The_Door.gmm
# -22.957323175695983
# Neveen_Open_The_Window.gmm
# -26.08476008807956
# Nur_Close_The_Door.gmm
# -28.024658755740717
# Nur_Close_The_Window.gmm
# -28.49970616328597
# Nur_Open_The_Door.gmm
# -24.60960290707882
# Nur_Open_The_Window.gmm
# -24.09478911422128
# Omar_Close_The_Door.gmm
# -25.81672302148593
# Omar_Close_The_Window.gmm
# -26.218780733668144
# Omar_Open_The_Door.gmm
# -23.547740733251754
# Omar_Open_The_Window.gmm
# -24.212127703085855
# Salman_Close_The_Door.gmm
# -23.473913364522986
# Salman_Close_The_Window.gmm
# -21.890864526123412
# Salman_Open_The_Door.gmm
# -20.13023463529621
# Salman_Open_The_Window.gmm
# -22.295128693709366
# 	detected as -  Salman_Open_The_Door
# MaxScore = -20.13023463529621
# --------------------------------------------------
# Accepted
# ##################################################
